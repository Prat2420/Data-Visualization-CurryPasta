# %% [markdown]
# Possible TO-DOs:
# - color nodes based on labeling;
# - color/have different shapes for edges based on their weights

# %% [markdown]
# # Step 6

# %% [markdown]
# - take the input graph (for instance Les Misérables network)
# - compute similarity matrix using graph-theoretic distance
# - project it using at least two different projections (MDS, t-SNE, ISOMAP)
# - draw the resulting layouts
# - compare/discuss the obtained layouts and parameter choices

# %%
import pandas as pd
import numpy as np
import pydot
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, ConnectionPatch
import graphviz
import networkx as nx
from networkx.drawing.nx_pydot import from_pydot
from collections import deque
import os
import math
import random
import re
from pathlib import Path
import matplotlib.cm as cm
from matplotlib.patches import Polygon, Patch, Rectangle
from scipy.spatial import ConvexHull
from sklearn.manifold import MDS, TSNE, Isomap
from sklearn.metrics import pairwise_distances

# %%
#names of the dot files that contain the data:
data_name_1 = "../Dataset/JazzNetwork.dot"
data_name_2 = "../Dataset/LesMiserables.dot" #
data_name_3 = "../Dataset/devonshiredebate_withclusters.dot"
data_name_4 = "../Dataset/g.20.27.dot"
data_name_5 = "../Dataset/g.42.88.dot"
data_name_6 = "../Dataset/GD97.dot"
data_name_7 = "../Dataset/LeagueNetwork.dot" 
data_name_8 = "../Dataset/mesh graph.dot"
data_name_9 = "../Dataset/noname.dot" 
data_name_10 = "../Dataset/polblogs.dot"
data_name_11 = "../Dataset/robot graph.dot"
data_name_12 = "../Dataset/rome.dot"
data_name_13 = "../Dataset/snail graph.dot"

# %% [markdown]
# # Functions

# %%
def floyd_warshall(nodes_dict, edges_dict):
    """
    Implements the Floyd-Warshall algorithm to find shortest paths between all pairs of nodes in a graph.
    
    Input:
    - nodes_dict: A list of dictionaries where each dict contains 'node_id' and other attributes
    - edges_dict: A list of dictionaries where each dict contains 'edge_nodes' (source, target) tuple
                  and other attributes including possibly weight information
    
    Output:
    - distance_matrix: A 2D matrix where distance_matrix[i][j] is the shortest path distance from node i to node j
    - node_ids: The list of node IDs in the order they appear in the distance matrix
    
    Algorithm explanation:
    The Floyd-Warshall algorithm finds shortest paths between all pairs of nodes by:
    1. Initializing a distance matrix D with infinity for all non-adjacent nodes
    2. Setting D[i,i] = 0 for all nodes (distance from a node to itself)
    3. Setting D[i,j] = weight for each direct edge (i,j)
    4. Considering each node k as a potential intermediate in paths between i and j
    5. If going through k yields a shorter path, updating D[i,j] accordingly
    
    Time Complexity: O(|V|³) where |V| is the number of nodes
    Space Complexity: O(|V|²)
    """
    
    # Extract node IDs from nodes_dict
    node_ids = [node['node_id'] for node in nodes_dict]
    n = len(node_ids)
    
    # Create node to index mapping for the matrix
    node_to_idx = {node_id: i for i, node_id in enumerate(node_ids)}
    
    # Initialize distance matrix with infinity
    distance_matrix = [[float('inf') for _ in range(n)] for _ in range(n)]
    
    # Set diagonal elements to 0 (distance from a node to itself)
    for i in range(n):
        distance_matrix[i][i] = 0
    
    # Set edge weights
    for edge in edges_dict:
        source, target = edge['edge_nodes']
        
        # Clean up node IDs (remove quotes if present)
        source = source.strip('"')
        target = target.strip('"')
        
        if source in node_to_idx and target in node_to_idx:
            # Determine the weight - look for a weight attribute, default to 1 if not found
            weight = 1
            if 'weight' in edge:
                try:
                    weight = float(edge['weight'].strip('"'))
                except (ValueError, AttributeError):
                    weight = 1
            elif 'len' in edge:
                try:
                    weight = float(edge['len'].strip('"'))
                except (ValueError, AttributeError):
                    weight = 1
                
            i, j = node_to_idx[source], node_to_idx[target]
            distance_matrix[i][j] = weight
            
            # If the graph is undirected, add the reverse edge as well
            # Uncomment this if your graph is undirected
            # distance_matrix[j][i] = weight
    
    # Floyd-Warshall algorithm
    for k in range(n):
        for i in range(n):
            for j in range(n):
                if distance_matrix[i][j] > distance_matrix[i][k] + distance_matrix[k][j]:
                    distance_matrix[i][j] = distance_matrix[i][k] + distance_matrix[k][j]
    
    return distance_matrix, node_ids

# Example usage
def get_shortest_distance(source, target, distance_matrix, node_ids):
    """
    Get the shortest distance between two nodes.
    
    Input:
    - source: The ID of the source node
    - target: The ID of the target node
    - distance_matrix: The distance matrix from floyd_warshall
    - node_ids: The list of node IDs from floyd_warshall
    
    Output:
    - The shortest distance from source to target
    """
    try:
        i = node_ids.index(source)
        j = node_ids.index(target)
        return distance_matrix[i][j]
    except ValueError:
        return "Node not found in the graph"
    
def plot_distance_matrix_with_weights(distance_matrix, node_ids=None, cmap='viridis_r', figsize=(10, 8)):
    """
    Visualizes the distance matrix from Floyd-Warshall algorithm as a heatmap with annotations.
    
    Parameters:
    - distance_matrix: 2D matrix of shortest path distances between all pairs of nodes
    - node_ids: List of node IDs in the order they appear in the distance matrix (optional)
    - cmap: Colormap to use for the heatmap (default: 'viridis_r')
    - figsize: Figure size (width, height) in inches
    
    Returns:
    - matplotlib figure and axes objects
    """
    import numpy as np
    import matplotlib.pyplot as plt
    
    # Convert to numpy array if not already
    distance_matrix = np.array(distance_matrix)
    
    # Create a masked array for infinity values
    mask = np.isinf(distance_matrix)
    masked_matrix = np.ma.masked_array(distance_matrix, mask)
    
    # Create figure and axes
    fig, ax = plt.subplots(figsize=figsize)
    
    # Plot heatmap
    im = ax.imshow(masked_matrix, cmap=cmap)
    
    # Add colorbar
    cbar = plt.colorbar(im, ax=ax)
    cbar.set_label('Shortest Path Distance')
    
    # Set title and labels
    ax.set_title('Shortest Path Distances (Floyd-Warshall Algorithm)')
    
    if node_ids is not None:
        # Clean node IDs (remove quotes if present)
        clean_node_ids = [nid.strip('"') if isinstance(nid, str) else nid for nid in node_ids]
        
        # Only show node labels if there are not too many
        if len(node_ids) <= 30:
            ax.set_xticks(np.arange(len(node_ids)))
            ax.set_yticks(np.arange(len(node_ids)))
            ax.set_xticklabels(clean_node_ids, rotation=45, ha='right')
            ax.set_yticklabels(clean_node_ids)
    
    ax.set_xlabel('Destination Node')
    ax.set_ylabel('Source Node')
    
    # Add text annotations with distances
    if distance_matrix.shape[0] <= 20:  # Only add annotations for smaller matrices
        for i in range(distance_matrix.shape[0]):
            for j in range(distance_matrix.shape[1]):
                value = distance_matrix[i, j]
                text = 'Inf' if np.isinf(value) else f'{value:.1f}'
                text_color = 'white' if not np.isinf(value) and value > np.nanmean(masked_matrix) else 'black'
                ax.text(j, i, text, ha='center', va='center', color=text_color)
    
    # Add a grid to better separate cells
    ax.set_xticks(np.arange(distance_matrix.shape[1]+1)-.5, minor=True)
    ax.set_yticks(np.arange(distance_matrix.shape[0]+1)-.5, minor=True)
    ax.grid(which="minor", color="w", linestyle='-', linewidth=1)
    
    plt.tight_layout()
    return fig, ax

# %% [markdown]
# # Usage:

# %% [markdown]
# ## take the input graph and compute similarity matrix using graph-theoretic distance

# %%
# Load the graph directly with NetworkX
nx_graph = nx.nx_pydot.read_dot(data_name_12)

# Check graph type
is_directed = nx.is_directed(nx_graph)
print(f"Graph is {'directed' if is_directed else 'undirected'}")

# Extract nodes and edges and their attributes
nodes = nx_graph.nodes(data=True)
edges = nx_graph.edges(data=True)

# Create an array of dictionaries, one for each edge
edges_dict = []
for source, target, attrs in edges:
    # Add the original edge direction
    edge_dict = {
        "edge_nodes": (source, target),
        "directed": is_directed
    }
    
    # Add all attributes from the attrs dictionary
    for attr_name, attr_value in attrs.items():    
        edge_dict[attr_name] = attr_value
    
    edges_dict.append(edge_dict)
    
    # For undirected graphs, add the reverse edge as well
    if not is_directed:
        reverse_edge_dict = {
            "edge_nodes": (target, source),
            "directed": is_directed
        }
        
        # Copy all attributes from the original edge
        for attr_name, attr_value in attrs.items():    
            reverse_edge_dict[attr_name] = attr_value
        
        edges_dict.append(reverse_edge_dict)

nodes_dict = []
for node_id, attrs in nodes:
    node_dict = {
        "node_id": node_id
    }
    
    # Add all attributes from the attrs dictionary
    for attr_name, attr_value in attrs.items():        
        node_dict[attr_name] = attr_value
    
    nodes_dict.append(node_dict)

# Basic graph information
print(f"Number of nodes: {len(nodes)}")
if is_directed:
    print(f"Number of edges: {len(edges)}")
else:
    print(f"Original Number of Edges:  {len(edges)} \n -- after doubling edges -- \nNumber of edges: {len(edges) * (2 if not is_directed else 1)}")
# Out:
# Graph is undirected
# Number of nodes: 100
# Original Number of Edges:  119
#  -- after doubling edges --
# Number of edges: 238

# %% [markdown]
# Calaculating shortest paths for all pairs of nodes in the graph with Floyd-Warshall’s Algorithm. Furthermore, we're calculating the distance matrix, to be able to run MDS, t-SNE and ISOMAP:

# %%
# Compute all-pairs shortest paths
distance_matrix, node_ids = floyd_warshall(nodes_dict, edges_dict)

# Example: Find shortest distance between all possible pairs of two nodes
for source in node_ids:
    for target in node_ids:
        if source != target:
            print(f"Shortest distance from {source} to {target}: {get_shortest_distance(source, target, distance_matrix, node_ids)}")
# Out:
# Shortest distance from n0 to n1: 5
# Shortest distance from n0 to n2: 2
# Shortest distance from n0 to n3: 3
# Shortest distance from n0 to n4: 3
# Shortest distance from n0 to n5: 4
# Shortest distance from n0 to n6: 6
# Shortest distance from n0 to n7: 5
# Shortest distance from n0 to n8: 2
# Shortest distance from n0 to n9: 1
# Shortest distance from n0 to n10: 7
# Shortest distance from n0 to n11: 4
# Shortest distance from n0 to n12: 4
# Shortest distance from n0 to n13: 9
# Shortest distance from n0 to n14: 7
# Shortest distance from n0 to n15: 7
# Shortest distance from n0 to n16: 4
# Shortest distance from n0 to n17: 8
# Shortest distance from n0 to n18: 9
# Shortest distance from n0 to n19: 5
# Shortest distance from n0 to n20: 4
# Shortest distance from n0 to n21: 6
# Shortest distance from n0 to n22: 7
# Shortest distance from n0 to n23: 7
# Shortest distance from n0 to n24: 6
# Shortest distance from n0 to n25: 9
# Shortest distance from n0 to n26: 6
# Shortest distance from n0 to n27: 3
# Shortest distance from n0 to n28: 5
# Shortest distance from n0 to n29: 6
# Shortest distance from n0 to n30: 8
# Shortest distance from n0 to n31: 7
# Shortest distance from n0 to n32: 2
# Shortest distance from n0 to n33: 4
# Shortest distance from n0 to n34: 5
# Shortest distance from n0 to n35: 8
# Shortest distance from n0 to n36: 5
# Shortest distance from n0 to n37: 7
# Shortest distance from n0 to n38: 8
# Shortest distance from n0 to n39: 3
# Shortest distance from n0 to n40: 4
# Shortest distance from n0 to n41: 5
# Shortest distance from n0 to n42: 6
# Shortest distance from n0 to n43: 6
# Shortest distance from n0 to n44: 8
# Shortest distance from n0 to n45: 7
# Shortest distance from n0 to n46: 4
# Shortest distance from n0 to n47: 4
# Shortest distance from n0 to n48: 4
# Shortest distance from n0 to n49: 5
# Shortest distance from n0 to n50: 7
# Shortest distance from n0 to n51: 4
# Shortest distance from n0 to n52: 3
# Shortest distance from n0 to n53: 2
# Shortest distance from n0 to n54: 5
# Shortest distance from n0 to n55: 5
# Shortest distance from n0 to n56: 8
# Shortest distance from n0 to n57: 5
# Shortest distance from n0 to n58: 7
# Shortest distance from n0 to n59: 6
# Shortest distance from n0 to n60: 9
# Shortest distance from n0 to n61: 8
# Shortest distance from n0 to n62: 3
# Shortest distance from n0 to n63: 9
# Shortest distance from n0 to n64: 4
# Shortest distance from n0 to n65: 9
# Shortest distance from n0 to n66: 8
# Shortest distance from n0 to n67: 7
# Shortest distance from n0 to n68: 9
# Shortest distance from n0 to n69: 5
# Shortest distance from n0 to n70: 5
# Shortest distance from n0 to n71: 6
# Shortest distance from n0 to n72: 6
# Shortest distance from n0 to n73: 7
# Shortest distance from n0 to n74: 8
# Shortest distance from n0 to n75: 6
# Shortest distance from n0 to n76: 5
# Shortest distance from n0 to n77: 7
# Shortest distance from n0 to n78: 6
# Shortest distance from n0 to n79: 1
# Shortest distance from n0 to n80: 6
# Shortest distance from n0 to n81: 5
# Shortest distance from n0 to n82: 6
# Shortest distance from n0 to n83: 3
# Shortest distance from n0 to n84: 7
# Shortest distance from n0 to n85: 7
# Shortest distance from n0 to n86: 5
# Shortest distance from n0 to n87: 6
# Shortest distance from n0 to n88: 9
# Shortest distance from n0 to n89: 9
# Shortest distance from n0 to n90: 6
# Shortest distance from n0 to n91: 6
# Shortest distance from n0 to n92: 2
# Shortest distance from n0 to n93: 4
# Shortest distance from n0 to n94: 8
# Shortest distance from n0 to n95: 5
# Shortest distance from n0 to n96: 4
# Shortest distance from n0 to n97: 7
# Shortest distance from n0 to n98: 1
# Shortest distance from n0 to n99: 7
# Shortest distance from n1 to n0: 5
# Shortest distance from n1 to n2: 7
# Shortest distance from n1 to n3: 4
# Shortest distance from n1 to n4: 7
# Shortest distance from n1 to n5: 8
# Shortest distance from n1 to n6: 3
# Shortest distance from n1 to n7: 2
# Shortest distance from n1 to n8: 7
# Shortest distance from n1 to n9: 6
# Shortest distance from n1 to n10: 5
# Shortest distance from n1 to n11: 1
# Shortest distance from n1 to n12: 6
# Shortest distance from n1 to n13: 10
# Shortest distance from n1 to n14: 2
# Shortest distance from n1 to n15: 6
# Shortest distance from n1 to n16: 5
# Shortest distance from n1 to n17: 9
# Shortest distance from n1 to n18: 8
# Shortest distance from n1 to n19: 6
# Shortest distance from n1 to n20: 3
# Shortest distance from n1 to n21: 7
# Shortest distance from n1 to n22: 8
# Shortest distance from n1 to n23: 8
# Shortest distance from n1 to n24: 7
# Shortest distance from n1 to n25: 4
# Shortest distance from n1 to n26: 7
# Shortest distance from n1 to n27: 2
# Shortest distance from n1 to n28: 6
# Shortest distance from n1 to n29: 7
# Shortest distance from n1 to n30: 4
# Shortest distance from n1 to n31: 8
# Shortest distance from n1 to n32: 3
# Shortest distance from n1 to n33: 5
# Shortest distance from n1 to n34: 8
# Shortest distance from n1 to n35: 9
# Shortest distance from n1 to n36: 6
# Shortest distance from n1 to n37: 2
# Shortest distance from n1 to n38: 5
# Shortest distance from n1 to n39: 4
# Shortest distance from n1 to n40: 5
# Shortest distance from n1 to n41: 6
# Shortest distance from n1 to n42: 7
# Shortest distance from n1 to n43: 7
# Shortest distance from n1 to n44: 3
# Shortest distance from n1 to n45: 5
# Shortest distance from n1 to n46: 5
# Shortest distance from n1 to n47: 5
# Shortest distance from n1 to n48: 5
# Shortest distance from n1 to n49: 6
# Shortest distance from n1 to n50: 8
# Shortest distance from n1 to n51: 7
# Shortest distance from n1 to n52: 6
# Shortest distance from n1 to n53: 5
# Shortest distance from n1 to n54: 4
# Shortest distance from n1 to n55: 5
# Shortest distance from n1 to n56: 6
# Shortest distance from n1 to n57: 8
# Shortest distance from n1 to n58: 8
# Shortest distance from n1 to n59: 8
# Shortest distance from n1 to n60: 4
# Shortest distance from n1 to n61: 3
# Shortest distance from n1 to n62: 4
# Shortest distance from n1 to n63: 4
# Shortest distance from n1 to n64: 3
# Shortest distance from n1 to n65: 5
# Shortest distance from n1 to n66: 3
# Shortest distance from n1 to n67: 7
# Shortest distance from n1 to n68: 5
# Shortest distance from n1 to n69: 4
# Shortest distance from n1 to n70: 4
# Shortest distance from n1 to n71: 5
# Shortest distance from n1 to n72: 6
# Shortest distance from n1 to n73: 8
# Shortest distance from n1 to n74: 7
# Shortest distance from n1 to n75: 1
# Shortest distance from n1 to n76: 4
# Shortest distance from n1 to n77: 8
# Shortest distance from n1 to n78: 5
# Shortest distance from n1 to n79: 4
# Shortest distance from n1 to n80: 7
# Shortest distance from n1 to n81: 6
# Shortest distance from n1 to n82: 7
# Shortest distance from n1 to n83: 4
# Shortest distance from n1 to n84: 8
# Shortest distance from n1 to n85: 8
# Shortest distance from n1 to n86: 7
# Shortest distance from n1 to n87: 7
# Shortest distance from n1 to n88: 10
# Shortest distance from n1 to n89: 6
# Shortest distance from n1 to n90: 4
# Shortest distance from n1 to n91: 1
# Shortest distance from n1 to n92: 7
# Shortest distance from n1 to n93: 5
# Shortest distance from n1 to n94: 7
# Shortest distance from n1 to n95: 5
# Shortest distance from n1 to n96: 5
# Shortest distance from n1 to n97: 2
# Shortest distance from n1 to n98: 6
# Shortest distance from n1 to n99: 8
# Shortest distance from n2 to n0: 2
# Shortest distance from n2 to n1: 7
# Shortest distance from n2 to n3: 5
# Shortest distance from n2 to n4: 1
# Shortest distance from n2 to n5: 2
# Shortest distance from n2 to n6: 7
# Shortest distance from n2 to n7: 7
# Shortest distance from n2 to n8: 3
# Shortest distance from n2 to n9: 1
# Shortest distance from n2 to n10: 8
# Shortest distance from n2 to n11: 6
# Shortest distance from n2 to n12: 2
# Shortest distance from n2 to n13: 11
# Shortest distance from n2 to n14: 9
# Shortest distance from n2 to n15: 9
# Shortest distance from n2 to n16: 3
# Shortest distance from n2 to n17: 10
# Shortest distance from n2 to n18: 11
# Shortest distance from n2 to n19: 6
# Shortest distance from n2 to n20: 6
# Shortest distance from n2 to n21: 7
# Shortest distance from n2 to n22: 8
# Shortest distance from n2 to n23: 8
# Shortest distance from n2 to n24: 8
# Shortest distance from n2 to n25: 11
# Shortest distance from n2 to n26: 7
# Shortest distance from n2 to n27: 5
# Shortest distance from n2 to n28: 6
# Shortest distance from n2 to n29: 7
# Shortest distance from n2 to n30: 9
# Shortest distance from n2 to n31: 8
# Shortest distance from n2 to n32: 4
# Shortest distance from n2 to n33: 5
# Shortest distance from n2 to n34: 7
# Shortest distance from n2 to n35: 10
# Shortest distance from n2 to n36: 7
# Shortest distance from n2 to n37: 9
# Shortest distance from n2 to n38: 9
# Shortest distance from n2 to n39: 4
# Shortest distance from n2 to n40: 6
# Shortest distance from n2 to n41: 6
# Shortest distance from n2 to n42: 7
# Shortest distance from n2 to n43: 8
# Shortest distance from n2 to n44: 10
# Shortest distance from n2 to n45: 8
# Shortest distance from n2 to n46: 5
# Shortest distance from n2 to n47: 5
# Shortest distance from n2 to n48: 5
# Shortest distance from n2 to n49: 6
# Shortest distance from n2 to n50: 9
# Shortest distance from n2 to n51: 6
# Shortest distance from n2 to n52: 5
# Shortest distance from n2 to n53: 4
# Shortest distance from n2 to n54: 6
# Shortest distance from n2 to n55: 5
# Shortest distance from n2 to n56: 9
# Shortest distance from n2 to n57: 7
# Shortest distance from n2 to n58: 9
# Shortest distance from n2 to n59: 4
# Shortest distance from n2 to n60: 11
# Shortest distance from n2 to n61: 10
# Shortest distance from n2 to n62: 5
# Shortest distance from n2 to n63: 10
# Shortest distance from n2 to n64: 6
# Shortest distance from n2 to n65: 10
# Shortest distance from n2 to n66: 10
# Shortest distance from n2 to n67: 8
# Shortest distance from n2 to n68: 10
# Shortest distance from n2 to n69: 7
# Shortest distance from n2 to n70: 7
# Shortest distance from n2 to n71: 7
# Shortest distance from n2 to n72: 6
# Shortest distance from n2 to n73: 8
# Shortest distance from n2 to n74: 9
# Shortest distance from n2 to n75: 8
# Shortest distance from n2 to n76: 7
# Shortest distance from n2 to n77: 8
# Shortest distance from n2 to n78: 8
# Shortest distance from n2 to n79: 3
# Shortest distance from n2 to n80: 7
# Shortest distance from n2 to n81: 4
# Shortest distance from n2 to n82: 7
# Shortest distance from n2 to n83: 5
# Shortest distance from n2 to n84: 9
# Shortest distance from n2 to n85: 8
# Shortest distance from n2 to n86: 3
# Shortest distance from n2 to n87: 7
# Shortest distance from n2 to n88: 11
# Shortest distance from n2 to n89: 10
# Shortest distance from n2 to n90: 7
# Shortest distance from n2 to n91: 8
# Shortest distance from n2 to n92: 2
# Shortest distance from n2 to n93: 5
# Shortest distance from n2 to n94: 10
# Shortest distance from n2 to n95: 6
# Shortest distance from n2 to n96: 5
# Shortest distance from n2 to n97: 9
# Shortest distance from n2 to n98: 3
# Shortest distance from n2 to n99: 9
# Shortest distance from n3 to n0: 3
# Shortest distance from n3 to n1: 4
# Shortest distance from n3 to n2: 5
# Shortest distance from n3 to n4: 5
# Shortest distance from n3 to n5: 6
# Shortest distance from n3 to n6: 5
# Shortest distance from n3 to n7: 4
# Shortest distance from n3 to n8: 5
# Shortest distance from n3 to n9: 4
# Shortest distance from n3 to n10: 6
# Shortest distance from n3 to n11: 3
# Shortest distance from n3 to n12: 4
# Shortest distance from n3 to n13: 8
# Shortest distance from n3 to n14: 6
# Shortest distance from n3 to n15: 6
# Shortest distance from n3 to n16: 3
# Shortest distance from n3 to n17: 7
# Shortest distance from n3 to n18: 8
# Shortest distance from n3 to n19: 4
# Shortest distance from n3 to n20: 3
# Shortest distance from n3 to n21: 5
# Shortest distance from n3 to n22: 6
# Shortest distance from n3 to n23: 6
# Shortest distance from n3 to n24: 5
# Shortest distance from n3 to n25: 8
# Shortest distance from n3 to n26: 5
# Shortest distance from n3 to n27: 2
# Shortest distance from n3 to n28: 4
# Shortest distance from n3 to n29: 5
# Shortest distance from n3 to n30: 7
# Shortest distance from n3 to n31: 6
# Shortest distance from n3 to n32: 1
# Shortest distance from n3 to n33: 3
# Shortest distance from n3 to n34: 6
# Shortest distance from n3 to n35: 7
# Shortest distance from n3 to n36: 4
# Shortest distance from n3 to n37: 6
# Shortest distance from n3 to n38: 7
# Shortest distance from n3 to n39: 2
# Shortest distance from n3 to n40: 3
# Shortest distance from n3 to n41: 4
# Shortest distance from n3 to n42: 5
# Shortest distance from n3 to n43: 5
# Shortest distance from n3 to n44: 7
# Shortest distance from n3 to n45: 6
# Shortest distance from n3 to n46: 3
# Shortest distance from n3 to n47: 3
# Shortest distance from n3 to n48: 3
# Shortest distance from n3 to n49: 4
# Shortest distance from n3 to n50: 6
# Shortest distance from n3 to n51: 5
# Shortest distance from n3 to n52: 4
# Shortest distance from n3 to n53: 3
# Shortest distance from n3 to n54: 4
# Shortest distance from n3 to n55: 4
# Shortest distance from n3 to n56: 7
# Shortest distance from n3 to n57: 6
# Shortest distance from n3 to n58: 6
# Shortest distance from n3 to n59: 6
# Shortest distance from n3 to n60: 8
# Shortest distance from n3 to n61: 7
# Shortest distance from n3 to n62: 2
# Shortest distance from n3 to n63: 8
# Shortest distance from n3 to n64: 3
# Shortest distance from n3 to n65: 8
# Shortest distance from n3 to n66: 7
# Shortest distance from n3 to n67: 6
# Shortest distance from n3 to n68: 8
# Shortest distance from n3 to n69: 4
# Shortest distance from n3 to n70: 4
# Shortest distance from n3 to n71: 5
# Shortest distance from n3 to n72: 5
# Shortest distance from n3 to n73: 6
# Shortest distance from n3 to n74: 7
# Shortest distance from n3 to n75: 5
# Shortest distance from n3 to n76: 4
# Shortest distance from n3 to n77: 6
# Shortest distance from n3 to n78: 5
# Shortest distance from n3 to n79: 2
# Shortest distance from n3 to n80: 5
# Shortest distance from n3 to n81: 4
# Shortest distance from n3 to n82: 5
# Shortest distance from n3 to n83: 1
# Shortest distance from n3 to n84: 6
# Shortest distance from n3 to n85: 6
# Shortest distance from n3 to n86: 5
# Shortest distance from n3 to n87: 5
# Shortest distance from n3 to n88: 8
# Shortest distance from n3 to n89: 8
# Shortest distance from n3 to n90: 5
# Shortest distance from n3 to n91: 5
# Shortest distance from n3 to n92: 5
# Shortest distance from n3 to n93: 3
# Shortest distance from n3 to n94: 7
# Shortest distance from n3 to n95: 4
# Shortest distance from n3 to n96: 3
# Shortest distance from n3 to n97: 6
# Shortest distance from n3 to n98: 4
# Shortest distance from n3 to n99: 6
# Shortest distance from n4 to n0: 3
# Shortest distance from n4 to n1: 7
# Shortest distance from n4 to n2: 1
# Shortest distance from n4 to n3: 5
# Shortest distance from n4 to n5: 1
# Shortest distance from n4 to n6: 6
# Shortest distance from n4 to n7: 7
# Shortest distance from n4 to n8: 4
# Shortest distance from n4 to n9: 2
# Shortest distance from n4 to n10: 7
# Shortest distance from n4 to n11: 6
# Shortest distance from n4 to n12: 1
# Shortest distance from n4 to n13: 11
# Shortest distance from n4 to n14: 9
# Shortest distance from n4 to n15: 9
# Shortest distance from n4 to n16: 2
# Shortest distance from n4 to n17: 10
# Shortest distance from n4 to n18: 11
# Shortest distance from n4 to n19: 5
# Shortest distance from n4 to n20: 6
# Shortest distance from n4 to n21: 6
# Shortest distance from n4 to n22: 7
# Shortest distance from n4 to n23: 7
# Shortest distance from n4 to n24: 8
# Shortest distance from n4 to n25: 10
# Shortest distance from n4 to n26: 6
# Shortest distance from n4 to n27: 5
# Shortest distance from n4 to n28: 5
# Shortest distance from n4 to n29: 6
# Shortest distance from n4 to n30: 8
# Shortest distance from n4 to n31: 7
# Shortest distance from n4 to n32: 4
# Shortest distance from n4 to n33: 4
# Shortest distance from n4 to n34: 8
# Shortest distance from n4 to n35: 9
# Shortest distance from n4 to n36: 7
# Shortest distance from n4 to n37: 9
# Shortest distance from n4 to n38: 8
# Shortest distance from n4 to n39: 3
# Shortest distance from n4 to n40: 6
# Shortest distance from n4 to n41: 5
# Shortest distance from n4 to n42: 6
# Shortest distance from n4 to n43: 8
# Shortest distance from n4 to n44: 10
# Shortest distance from n4 to n45: 7
# Shortest distance from n4 to n46: 4
# Shortest distance from n4 to n47: 4
# Shortest distance from n4 to n48: 4
# Shortest distance from n4 to n49: 5
# Shortest distance from n4 to n50: 9
# Shortest distance from n4 to n51: 7
# Shortest distance from n4 to n52: 6
# Shortest distance from n4 to n53: 5
# Shortest distance from n4 to n54: 5
# Shortest distance from n4 to n55: 4
# Shortest distance from n4 to n56: 8
# Shortest distance from n4 to n57: 8
# Shortest distance from n4 to n58: 9
# Shortest distance from n4 to n59: 3
# Shortest distance from n4 to n60: 11
# Shortest distance from n4 to n61: 9
# Shortest distance from n4 to n62: 5
# Shortest distance from n4 to n63: 9
# Shortest distance from n4 to n64: 6
# Shortest distance from n4 to n65: 9
# Shortest distance from n4 to n66: 10
# Shortest distance from n4 to n67: 7
# Shortest distance from n4 to n68: 9
# Shortest distance from n4 to n69: 7
# Shortest distance from n4 to n70: 7
# Shortest distance from n4 to n71: 6
# Shortest distance from n4 to n72: 5
# Shortest distance from n4 to n73: 7
# Shortest distance from n4 to n74: 8
# Shortest distance from n4 to n75: 8
# Shortest distance from n4 to n76: 7
# Shortest distance from n4 to n77: 7
# Shortest distance from n4 to n78: 8
# Shortest distance from n4 to n79: 4
# Shortest distance from n4 to n80: 6
# Shortest distance from n4 to n81: 3
# Shortest distance from n4 to n82: 6
# Shortest distance from n4 to n83: 5
# Shortest distance from n4 to n84: 9
# Shortest distance from n4 to n85: 7
# Shortest distance from n4 to n86: 2
# Shortest distance from n4 to n87: 6
# Shortest distance from n4 to n88: 11
# Shortest distance from n4 to n89: 9
# Shortest distance from n4 to n90: 6
# Shortest distance from n4 to n91: 8
# Shortest distance from n4 to n92: 3
# Shortest distance from n4 to n93: 4
# Shortest distance from n4 to n94: 10
# Shortest distance from n4 to n95: 5
# Shortest distance from n4 to n96: 4
# Shortest distance from n4 to n97: 9
# Shortest distance from n4 to n98: 4
# Shortest distance from n4 to n99: 8
# Shortest distance from n5 to n0: 4
# Shortest distance from n5 to n1: 8
# Shortest distance from n5 to n2: 2
# Shortest distance from n5 to n3: 6
# Shortest distance from n5 to n4: 1
# Shortest distance from n5 to n6: 7
# Shortest distance from n5 to n7: 8
# Shortest distance from n5 to n8: 5
# Shortest distance from n5 to n9: 3
# Shortest distance from n5 to n10: 8
# Shortest distance from n5 to n11: 7
# Shortest distance from n5 to n12: 2
# Shortest distance from n5 to n13: 12
# Shortest distance from n5 to n14: 10
# Shortest distance from n5 to n15: 10
# Shortest distance from n5 to n16: 3
# Shortest distance from n5 to n17: 11
# Shortest distance from n5 to n18: 12
# Shortest distance from n5 to n19: 6
# Shortest distance from n5 to n20: 7
# Shortest distance from n5 to n21: 7
# Shortest distance from n5 to n22: 8
# Shortest distance from n5 to n23: 8
# Shortest distance from n5 to n24: 9
# Shortest distance from n5 to n25: 11
# Shortest distance from n5 to n26: 7
# Shortest distance from n5 to n27: 6
# Shortest distance from n5 to n28: 6
# Shortest distance from n5 to n29: 7
# Shortest distance from n5 to n30: 9
# Shortest distance from n5 to n31: 8
# Shortest distance from n5 to n32: 5
# Shortest distance from n5 to n33: 5
# Shortest distance from n5 to n34: 9
# Shortest distance from n5 to n35: 10
# Shortest distance from n5 to n36: 8
# Shortest distance from n5 to n37: 10
# Shortest distance from n5 to n38: 9
# Shortest distance from n5 to n39: 4
# Shortest distance from n5 to n40: 7
# Shortest distance from n5 to n41: 6
# Shortest distance from n5 to n42: 7
# Shortest distance from n5 to n43: 9
# Shortest distance from n5 to n44: 11
# Shortest distance from n5 to n45: 8
# Shortest distance from n5 to n46: 5
# Shortest distance from n5 to n47: 5
# Shortest distance from n5 to n48: 5
# Shortest distance from n5 to n49: 6
# Shortest distance from n5 to n50: 10
# Shortest distance from n5 to n51: 8
# Shortest distance from n5 to n52: 7
# Shortest distance from n5 to n53: 6
# Shortest distance from n5 to n54: 6
# Shortest distance from n5 to n55: 5
# Shortest distance from n5 to n56: 9
# Shortest distance from n5 to n57: 9
# Shortest distance from n5 to n58: 10
# Shortest distance from n5 to n59: 4
# Shortest distance from n5 to n60: 12
# Shortest distance from n5 to n61: 10
# Shortest distance from n5 to n62: 6
# Shortest distance from n5 to n63: 10
# Shortest distance from n5 to n64: 7
# Shortest distance from n5 to n65: 10
# Shortest distance from n5 to n66: 11
# Shortest distance from n5 to n67: 8
# Shortest distance from n5 to n68: 10
# Shortest distance from n5 to n69: 8
# Shortest distance from n5 to n70: 8
# Shortest distance from n5 to n71: 7
# Shortest distance from n5 to n72: 6
# Shortest distance from n5 to n73: 8
# Shortest distance from n5 to n74: 9
# Shortest distance from n5 to n75: 9
# Shortest distance from n5 to n76: 8
# Shortest distance from n5 to n77: 8
# Shortest distance from n5 to n78: 9
# Shortest distance from n5 to n79: 5
# Shortest distance from n5 to n80: 7
# Shortest distance from n5 to n81: 4
# Shortest distance from n5 to n82: 7
# Shortest distance from n5 to n83: 6
# Shortest distance from n5 to n84: 10
# Shortest distance from n5 to n85: 8
# Shortest distance from n5 to n86: 3
# Shortest distance from n5 to n87: 7
# Shortest distance from n5 to n88: 12
# Shortest distance from n5 to n89: 10
# Shortest distance from n5 to n90: 7
# Shortest distance from n5 to n91: 9
# Shortest distance from n5 to n92: 4
# Shortest distance from n5 to n93: 5
# Shortest distance from n5 to n94: 11
# Shortest distance from n5 to n95: 6
# Shortest distance from n5 to n96: 5
# Shortest distance from n5 to n97: 10
# Shortest distance from n5 to n98: 5
# Shortest distance from n5 to n99: 9
# Shortest distance from n6 to n0: 6
# Shortest distance from n6 to n1: 3
# Shortest distance from n6 to n2: 7
# Shortest distance from n6 to n3: 5
# Shortest distance from n6 to n4: 6
# Shortest distance from n6 to n5: 7
# Shortest distance from n6 to n7: 1
# Shortest distance from n6 to n8: 8
# Shortest distance from n6 to n9: 7
# Shortest distance from n6 to n10: 2
# Shortest distance from n6 to n11: 2
# Shortest distance from n6 to n12: 5
# Shortest distance from n6 to n13: 11
# Shortest distance from n6 to n14: 5
# Shortest distance from n6 to n15: 7
# Shortest distance from n6 to n16: 4
# Shortest distance from n6 to n17: 10
# Shortest distance from n6 to n18: 9
# Shortest distance from n6 to n19: 4
# Shortest distance from n6 to n20: 4
# Shortest distance from n6 to n21: 5
# Shortest distance from n6 to n22: 7
# Shortest distance from n6 to n23: 6
# Shortest distance from n6 to n24: 8
# Shortest distance from n6 to n25: 7
# Shortest distance from n6 to n26: 5
# Shortest distance from n6 to n27: 3
# Shortest distance from n6 to n28: 4
# Shortest distance from n6 to n29: 5
# Shortest distance from n6 to n30: 7
# Shortest distance from n6 to n31: 6
# Shortest distance from n6 to n32: 4
# Shortest distance from n6 to n33: 5
# Shortest distance from n6 to n34: 9
# Shortest distance from n6 to n35: 8
# Shortest distance from n6 to n36: 7
# Shortest distance from n6 to n37: 5
# Shortest distance from n6 to n38: 8
# Shortest distance from n6 to n39: 4
# Shortest distance from n6 to n40: 6
# Shortest distance from n6 to n41: 6
# Shortest distance from n6 to n42: 7
# Shortest distance from n6 to n43: 8
# Shortest distance from n6 to n44: 6
# Shortest distance from n6 to n45: 7
# Shortest distance from n6 to n46: 3
# Shortest distance from n6 to n47: 5
# Shortest distance from n6 to n48: 5
# Shortest distance from n6 to n49: 6
# Shortest distance from n6 to n50: 9
# Shortest distance from n6 to n51: 8
# Shortest distance from n6 to n52: 7
# Shortest distance from n6 to n53: 6
# Shortest distance from n6 to n54: 1
# Shortest distance from n6 to n55: 2
# Shortest distance from n6 to n56: 8
# Shortest distance from n6 to n57: 9
# Shortest distance from n6 to n58: 9
# Shortest distance from n6 to n59: 7
# Shortest distance from n6 to n60: 7
# Shortest distance from n6 to n61: 6
# Shortest distance from n6 to n62: 5
# Shortest distance from n6 to n63: 7
# Shortest distance from n6 to n64: 2
# Shortest distance from n6 to n65: 8
# Shortest distance from n6 to n66: 6
# Shortest distance from n6 to n67: 8
# Shortest distance from n6 to n68: 8
# Shortest distance from n6 to n69: 3
# Shortest distance from n6 to n70: 5
# Shortest distance from n6 to n71: 6
# Shortest distance from n6 to n72: 3
# Shortest distance from n6 to n73: 6
# Shortest distance from n6 to n74: 7
# Shortest distance from n6 to n75: 4
# Shortest distance from n6 to n76: 5
# Shortest distance from n6 to n77: 6
# Shortest distance from n6 to n78: 6
# Shortest distance from n6 to n79: 5
# Shortest distance from n6 to n80: 7
# Shortest distance from n6 to n81: 3
# Shortest distance from n6 to n82: 7
# Shortest distance from n6 to n83: 5
# Shortest distance from n6 to n84: 9
# Shortest distance from n6 to n85: 6
# Shortest distance from n6 to n86: 6
# Shortest distance from n6 to n87: 5
# Shortest distance from n6 to n88: 11
# Shortest distance from n6 to n89: 8
# Shortest distance from n6 to n90: 1
# Shortest distance from n6 to n91: 4
# Shortest distance from n6 to n92: 8
# Shortest distance from n6 to n93: 3
# Shortest distance from n6 to n94: 8
# Shortest distance from n6 to n95: 2
# Shortest distance from n6 to n96: 5
# Shortest distance from n6 to n97: 5
# Shortest distance from n6 to n98: 7
# Shortest distance from n6 to n99: 7
# Shortest distance from n7 to n0: 5
# Shortest distance from n7 to n1: 2
# Shortest distance from n7 to n2: 7
# Shortest distance from n7 to n3: 4
# Shortest distance from n7 to n4: 7
# Shortest distance from n7 to n5: 8
# Shortest distance from n7 to n6: 1
# Shortest distance from n7 to n8: 7
# Shortest distance from n7 to n9: 6
# Shortest distance from n7 to n10: 3
# Shortest distance from n7 to n11: 1
# Shortest distance from n7 to n12: 6
# Shortest distance from n7 to n13: 10
# Shortest distance from n7 to n14: 4
# Shortest distance from n7 to n15: 6
# Shortest distance from n7 to n16: 5
# Shortest distance from n7 to n17: 9
# Shortest distance from n7 to n18: 8
# Shortest distance from n7 to n19: 5
# Shortest distance from n7 to n20: 3
# Shortest distance from n7 to n21: 6
# Shortest distance from n7 to n22: 8
# Shortest distance from n7 to n23: 7
# Shortest distance from n7 to n24: 7
# Shortest distance from n7 to n25: 6
# Shortest distance from n7 to n26: 6
# Shortest distance from n7 to n27: 2
# Shortest distance from n7 to n28: 5
# Shortest distance from n7 to n29: 6
# Shortest distance from n7 to n30: 6
# Shortest distance from n7 to n31: 7
# Shortest distance from n7 to n32: 3
# Shortest distance from n7 to n33: 5
# Shortest distance from n7 to n34: 8
# Shortest distance from n7 to n35: 9
# Shortest distance from n7 to n36: 6
# Shortest distance from n7 to n37: 4
# Shortest distance from n7 to n38: 7
# Shortest distance from n7 to n39: 4
# Shortest distance from n7 to n40: 5
# Shortest distance from n7 to n41: 6
# Shortest distance from n7 to n42: 7
# Shortest distance from n7 to n43: 7
# Shortest distance from n7 to n44: 5
# Shortest distance from n7 to n45: 6
# Shortest distance from n7 to n46: 4
# Shortest distance from n7 to n47: 5
# Shortest distance from n7 to n48: 5
# Shortest distance from n7 to n49: 6
# Shortest distance from n7 to n50: 8
# Shortest distance from n7 to n51: 7
# Shortest distance from n7 to n52: 6
# Shortest distance from n7 to n53: 5
# Shortest distance from n7 to n54: 2
# Shortest distance from n7 to n55: 3
# Shortest distance from n7 to n56: 7
# Shortest distance from n7 to n57: 8
# Shortest distance from n7 to n58: 8
# Shortest distance from n7 to n59: 8
# Shortest distance from n7 to n60: 6
# Shortest distance from n7 to n61: 5
# Shortest distance from n7 to n62: 4
# Shortest distance from n7 to n63: 6
# Shortest distance from n7 to n64: 3
# Shortest distance from n7 to n65: 7
# Shortest distance from n7 to n66: 5
# Shortest distance from n7 to n67: 8
# Shortest distance from n7 to n68: 7
# Shortest distance from n7 to n69: 4
# Shortest distance from n7 to n70: 4
# Shortest distance from n7 to n71: 5
# Shortest distance from n7 to n72: 4
# Shortest distance from n7 to n73: 7
# Shortest distance from n7 to n74: 8
# Shortest distance from n7 to n75: 3
# Shortest distance from n7 to n76: 4
# Shortest distance from n7 to n77: 7
# Shortest distance from n7 to n78: 5
# Shortest distance from n7 to n79: 4
# Shortest distance from n7 to n80: 7
# Shortest distance from n7 to n81: 4
# Shortest distance from n7 to n82: 7
# Shortest distance from n7 to n83: 4
# Shortest distance from n7 to n84: 8
# Shortest distance from n7 to n85: 7
# Shortest distance from n7 to n86: 7
# Shortest distance from n7 to n87: 6
# Shortest distance from n7 to n88: 10
# Shortest distance from n7 to n89: 8
# Shortest distance from n7 to n90: 2
# Shortest distance from n7 to n91: 3
# Shortest distance from n7 to n92: 7
# Shortest distance from n7 to n93: 4
# Shortest distance from n7 to n94: 7
# Shortest distance from n7 to n95: 3
# Shortest distance from n7 to n96: 5
# Shortest distance from n7 to n97: 4
# Shortest distance from n7 to n98: 6
# Shortest distance from n7 to n99: 8
# Shortest distance from n8 to n0: 2
# Shortest distance from n8 to n1: 7
# Shortest distance from n8 to n2: 3
# Shortest distance from n8 to n3: 5
# Shortest distance from n8 to n4: 4
# Shortest distance from n8 to n5: 5
# Shortest distance from n8 to n6: 8
# Shortest distance from n8 to n7: 7
# Shortest distance from n8 to n9: 2
# Shortest distance from n8 to n10: 9
# Shortest distance from n8 to n11: 6
# Shortest distance from n8 to n12: 5
# Shortest distance from n8 to n13: 11
# Shortest distance from n8 to n14: 9
# Shortest distance from n8 to n15: 9
# Shortest distance from n8 to n16: 6
# Shortest distance from n8 to n17: 10
# Shortest distance from n8 to n18: 11
# Shortest distance from n8 to n19: 7
# Shortest distance from n8 to n20: 6
# Shortest distance from n8 to n21: 8
# Shortest distance from n8 to n22: 9
# Shortest distance from n8 to n23: 9
# Shortest distance from n8 to n24: 8
# Shortest distance from n8 to n25: 11
# Shortest distance from n8 to n26: 8
# Shortest distance from n8 to n27: 5
# Shortest distance from n8 to n28: 7
# Shortest distance from n8 to n29: 8
# Shortest distance from n8 to n30: 10
# Shortest distance from n8 to n31: 9
# Shortest distance from n8 to n32: 4
# Shortest distance from n8 to n33: 6
# Shortest distance from n8 to n34: 7
# Shortest distance from n8 to n35: 10
# Shortest distance from n8 to n36: 7
# Shortest distance from n8 to n37: 9
# Shortest distance from n8 to n38: 10
# Shortest distance from n8 to n39: 5
# Shortest distance from n8 to n40: 6
# Shortest distance from n8 to n41: 7
# Shortest distance from n8 to n42: 8
# Shortest distance from n8 to n43: 8
# Shortest distance from n8 to n44: 10
# Shortest distance from n8 to n45: 9
# Shortest distance from n8 to n46: 6
# Shortest distance from n8 to n47: 6
# Shortest distance from n8 to n48: 6
# Shortest distance from n8 to n49: 7
# Shortest distance from n8 to n50: 9
# Shortest distance from n8 to n51: 6
# Shortest distance from n8 to n52: 5
# Shortest distance from n8 to n53: 4
# Shortest distance from n8 to n54: 7
# Shortest distance from n8 to n55: 7
# Shortest distance from n8 to n56: 10
# Shortest distance from n8 to n57: 7
# Shortest distance from n8 to n58: 9
# Shortest distance from n8 to n59: 7
# Shortest distance from n8 to n60: 11
# Shortest distance from n8 to n61: 10
# Shortest distance from n8 to n62: 5
# Shortest distance from n8 to n63: 11
# Shortest distance from n8 to n64: 6
# Shortest distance from n8 to n65: 11
# Shortest distance from n8 to n66: 10
# Shortest distance from n8 to n67: 9
# Shortest distance from n8 to n68: 11
# Shortest distance from n8 to n69: 7
# Shortest distance from n8 to n70: 7
# Shortest distance from n8 to n71: 8
# Shortest distance from n8 to n72: 8
# Shortest distance from n8 to n73: 9
# Shortest distance from n8 to n74: 10
# Shortest distance from n8 to n75: 8
# Shortest distance from n8 to n76: 7
# Shortest distance from n8 to n77: 9
# Shortest distance from n8 to n78: 8
# Shortest distance from n8 to n79: 3
# Shortest distance from n8 to n80: 8
# Shortest distance from n8 to n81: 7
# Shortest distance from n8 to n82: 8
# Shortest distance from n8 to n83: 5
# Shortest distance from n8 to n84: 9
# Shortest distance from n8 to n85: 9
# Shortest distance from n8 to n86: 6
# Shortest distance from n8 to n87: 8
# Shortest distance from n8 to n88: 11
# Shortest distance from n8 to n89: 11
# Shortest distance from n8 to n90: 8
# Shortest distance from n8 to n91: 8
# Shortest distance from n8 to n92: 1
# Shortest distance from n8 to n93: 6
# Shortest distance from n8 to n94: 10
# Shortest distance from n8 to n95: 7
# Shortest distance from n8 to n96: 6
# Shortest distance from n8 to n97: 9
# Shortest distance from n8 to n98: 1
# Shortest distance from n8 to n99: 9
# Shortest distance from n9 to n0: 1
# Shortest distance from n9 to n1: 6
# Shortest distance from n9 to n2: 1
# Shortest distance from n9 to n3: 4
# Shortest distance from n9 to n4: 2
# Shortest distance from n9 to n5: 3
# Shortest distance from n9 to n6: 7
# Shortest distance from n9 to n7: 6
# Shortest distance from n9 to n8: 2
# Shortest distance from n9 to n10: 8
# Shortest distance from n9 to n11: 5
# Shortest distance from n9 to n12: 3
# Shortest distance from n9 to n13: 10
# Shortest distance from n9 to n14: 8
# Shortest distance from n9 to n15: 8
# Shortest distance from n9 to n16: 4
# Shortest distance from n9 to n17: 9
# Shortest distance from n9 to n18: 10
# Shortest distance from n9 to n19: 6
# Shortest distance from n9 to n20: 5
# Shortest distance from n9 to n21: 7
# Shortest distance from n9 to n22: 8
# Shortest distance from n9 to n23: 8
# Shortest distance from n9 to n24: 7
# Shortest distance from n9 to n25: 10
# Shortest distance from n9 to n26: 7
# Shortest distance from n9 to n27: 4
# Shortest distance from n9 to n28: 6
# Shortest distance from n9 to n29: 7
# Shortest distance from n9 to n30: 9
# Shortest distance from n9 to n31: 8
# Shortest distance from n9 to n32: 3
# Shortest distance from n9 to n33: 5
# Shortest distance from n9 to n34: 6
# Shortest distance from n9 to n35: 9
# Shortest distance from n9 to n36: 6
# Shortest distance from n9 to n37: 8
# Shortest distance from n9 to n38: 9
# Shortest distance from n9 to n39: 4
# Shortest distance from n9 to n40: 5
# Shortest distance from n9 to n41: 6
# Shortest distance from n9 to n42: 7
# Shortest distance from n9 to n43: 7
# Shortest distance from n9 to n44: 9
# Shortest distance from n9 to n45: 8
# Shortest distance from n9 to n46: 5
# Shortest distance from n9 to n47: 5
# Shortest distance from n9 to n48: 5
# Shortest distance from n9 to n49: 6
# Shortest distance from n9 to n50: 8
# Shortest distance from n9 to n51: 5
# Shortest distance from n9 to n52: 4
# Shortest distance from n9 to n53: 3
# Shortest distance from n9 to n54: 6
# Shortest distance from n9 to n55: 6
# Shortest distance from n9 to n56: 9
# Shortest distance from n9 to n57: 6
# Shortest distance from n9 to n58: 8
# Shortest distance from n9 to n59: 5
# Shortest distance from n9 to n60: 10
# Shortest distance from n9 to n61: 9
# Shortest distance from n9 to n62: 4
# Shortest distance from n9 to n63: 10
# Shortest distance from n9 to n64: 5
# Shortest distance from n9 to n65: 10
# Shortest distance from n9 to n66: 9
# Shortest distance from n9 to n67: 8
# Shortest distance from n9 to n68: 10
# Shortest distance from n9 to n69: 6
# Shortest distance from n9 to n70: 6
# Shortest distance from n9 to n71: 7
# Shortest distance from n9 to n72: 7
# Shortest distance from n9 to n73: 8
# Shortest distance from n9 to n74: 9
# Shortest distance from n9 to n75: 7
# Shortest distance from n9 to n76: 6
# Shortest distance from n9 to n77: 8
# Shortest distance from n9 to n78: 7
# Shortest distance from n9 to n79: 2
# Shortest distance from n9 to n80: 7
# Shortest distance from n9 to n81: 5
# Shortest distance from n9 to n82: 7
# Shortest distance from n9 to n83: 4
# Shortest distance from n9 to n84: 8
# Shortest distance from n9 to n85: 8
# Shortest distance from n9 to n86: 4
# Shortest distance from n9 to n87: 7
# Shortest distance from n9 to n88: 10
# Shortest distance from n9 to n89: 10
# Shortest distance from n9 to n90: 7
# Shortest distance from n9 to n91: 7
# Shortest distance from n9 to n92: 1
# Shortest distance from n9 to n93: 5
# Shortest distance from n9 to n94: 9
# Shortest distance from n9 to n95: 6
# Shortest distance from n9 to n96: 5
# Shortest distance from n9 to n97: 8
# Shortest distance from n9 to n98: 2
# Shortest distance from n9 to n99: 8
# Shortest distance from n10 to n0: 7
# Shortest distance from n10 to n1: 5
# Shortest distance from n10 to n2: 8
# Shortest distance from n10 to n3: 6
# Shortest distance from n10 to n4: 7
# Shortest distance from n10 to n5: 8
# Shortest distance from n10 to n6: 2
# Shortest distance from n10 to n7: 3
# Shortest distance from n10 to n8: 9
# Shortest distance from n10 to n9: 8
# Shortest distance from n10 to n11: 4
# Shortest distance from n10 to n12: 6
# Shortest distance from n10 to n13: 12
# Shortest distance from n10 to n14: 7
# Shortest distance from n10 to n15: 9
# Shortest distance from n10 to n16: 5
# Shortest distance from n10 to n17: 11
# Shortest distance from n10 to n18: 11
# Shortest distance from n10 to n19: 4
# Shortest distance from n10 to n20: 6
# Shortest distance from n10 to n21: 5
# Shortest distance from n10 to n22: 7
# Shortest distance from n10 to n23: 6
# Shortest distance from n10 to n24: 8
# Shortest distance from n10 to n25: 9
# Shortest distance from n10 to n26: 5
# Shortest distance from n10 to n27: 5
# Shortest distance from n10 to n28: 4
# Shortest distance from n10 to n29: 5
# Shortest distance from n10 to n30: 9
# Shortest distance from n10 to n31: 6
# Shortest distance from n10 to n32: 5
# Shortest distance from n10 to n33: 5
# Shortest distance from n10 to n34: 9
# Shortest distance from n10 to n35: 8
# Shortest distance from n10 to n36: 8
# Shortest distance from n10 to n37: 7
# Shortest distance from n10 to n38: 9
# Shortest distance from n10 to n39: 4
# Shortest distance from n10 to n40: 7
# Shortest distance from n10 to n41: 6
# Shortest distance from n10 to n42: 7
# Shortest distance from n10 to n43: 9
# Shortest distance from n10 to n44: 8
# Shortest distance from n10 to n45: 8
# Shortest distance from n10 to n46: 3
# Shortest distance from n10 to n47: 5
# Shortest distance from n10 to n48: 5
# Shortest distance from n10 to n49: 6
# Shortest distance from n10 to n50: 10
# Shortest distance from n10 to n51: 9
# Shortest distance from n10 to n52: 8
# Shortest distance from n10 to n53: 7
# Shortest distance from n10 to n54: 3
# Shortest distance from n10 to n55: 4
# Shortest distance from n10 to n56: 9
# Shortest distance from n10 to n57: 10
# Shortest distance from n10 to n58: 9
# Shortest distance from n10 to n59: 8
# Shortest distance from n10 to n60: 9
# Shortest distance from n10 to n61: 8
# Shortest distance from n10 to n62: 6
# Shortest distance from n10 to n63: 9
# Shortest distance from n10 to n64: 4
# Shortest distance from n10 to n65: 9
# Shortest distance from n10 to n66: 8
# Shortest distance from n10 to n67: 8
# Shortest distance from n10 to n68: 10
# Shortest distance from n10 to n69: 5
# Shortest distance from n10 to n70: 7
# Shortest distance from n10 to n71: 7
# Shortest distance from n10 to n72: 5
# Shortest distance from n10 to n73: 6
# Shortest distance from n10 to n74: 7
# Shortest distance from n10 to n75: 6
# Shortest distance from n10 to n76: 7
# Shortest distance from n10 to n77: 6
# Shortest distance from n10 to n78: 8
# Shortest distance from n10 to n79: 6
# Shortest distance from n10 to n80: 7
# Shortest distance from n10 to n81: 5
# Shortest distance from n10 to n82: 7
# Shortest distance from n10 to n83: 6
# Shortest distance from n10 to n84: 9
# Shortest distance from n10 to n85: 6
# Shortest distance from n10 to n86: 7
# Shortest distance from n10 to n87: 5
# Shortest distance from n10 to n88: 12
# Shortest distance from n10 to n89: 8
# Shortest distance from n10 to n90: 1
# Shortest distance from n10 to n91: 6
# Shortest distance from n10 to n92: 9
# Shortest distance from n10 to n93: 3
# Shortest distance from n10 to n94: 10
# Shortest distance from n10 to n95: 2
# Shortest distance from n10 to n96: 5
# Shortest distance from n10 to n97: 7
# Shortest distance from n10 to n98: 8
# Shortest distance from n10 to n99: 7
# Shortest distance from n11 to n0: 4
# Shortest distance from n11 to n1: 1
# Shortest distance from n11 to n2: 6
# Shortest distance from n11 to n3: 3
# Shortest distance from n11 to n4: 6
# Shortest distance from n11 to n5: 7
# Shortest distance from n11 to n6: 2
# Shortest distance from n11 to n7: 1
# Shortest distance from n11 to n8: 6
# Shortest distance from n11 to n9: 5
# Shortest distance from n11 to n10: 4
# Shortest distance from n11 to n12: 5
# Shortest distance from n11 to n13: 9
# Shortest distance from n11 to n14: 3
# Shortest distance from n11 to n15: 5
# Shortest distance from n11 to n16: 4
# Shortest distance from n11 to n17: 8
# Shortest distance from n11 to n18: 7
# Shortest distance from n11 to n19: 5
# Shortest distance from n11 to n20: 2
# Shortest distance from n11 to n21: 6
# Shortest distance from n11 to n22: 7
# Shortest distance from n11 to n23: 7
# Shortest distance from n11 to n24: 6
# Shortest distance from n11 to n25: 5
# Shortest distance from n11 to n26: 6
# Shortest distance from n11 to n27: 1
# Shortest distance from n11 to n28: 5
# Shortest distance from n11 to n29: 6
# Shortest distance from n11 to n30: 5
# Shortest distance from n11 to n31: 7
# Shortest distance from n11 to n32: 2
# Shortest distance from n11 to n33: 4
# Shortest distance from n11 to n34: 7
# Shortest distance from n11 to n35: 8
# Shortest distance from n11 to n36: 5
# Shortest distance from n11 to n37: 3
# Shortest distance from n11 to n38: 6
# Shortest distance from n11 to n39: 3
# Shortest distance from n11 to n40: 4
# Shortest distance from n11 to n41: 5
# Shortest distance from n11 to n42: 6
# Shortest distance from n11 to n43: 6
# Shortest distance from n11 to n44: 4
# Shortest distance from n11 to n45: 5
# Shortest distance from n11 to n46: 4
# Shortest distance from n11 to n47: 4
# Shortest distance from n11 to n48: 4
# Shortest distance from n11 to n49: 5
# Shortest distance from n11 to n50: 7
# Shortest distance from n11 to n51: 6
# Shortest distance from n11 to n52: 5
# Shortest distance from n11 to n53: 4
# Shortest distance from n11 to n54: 3
# Shortest distance from n11 to n55: 4
# Shortest distance from n11 to n56: 6
# Shortest distance from n11 to n57: 7
# Shortest distance from n11 to n58: 7
# Shortest distance from n11 to n59: 7
# Shortest distance from n11 to n60: 5
# Shortest distance from n11 to n61: 4
# Shortest distance from n11 to n62: 3
# Shortest distance from n11 to n63: 5
# Shortest distance from n11 to n64: 2
# Shortest distance from n11 to n65: 6
# Shortest distance from n11 to n66: 4
# Shortest distance from n11 to n67: 7
# Shortest distance from n11 to n68: 6
# Shortest distance from n11 to n69: 3
# Shortest distance from n11 to n70: 3
# Shortest distance from n11 to n71: 4
# Shortest distance from n11 to n72: 5
# Shortest distance from n11 to n73: 7
# Shortest distance from n11 to n74: 8
# Shortest distance from n11 to n75: 2
# Shortest distance from n11 to n76: 3
# Shortest distance from n11 to n77: 7
# Shortest distance from n11 to n78: 4
# Shortest distance from n11 to n79: 3
# Shortest distance from n11 to n80: 6
# Shortest distance from n11 to n81: 5
# Shortest distance from n11 to n82: 6
# Shortest distance from n11 to n83: 3
# Shortest distance from n11 to n84: 7
# Shortest distance from n11 to n85: 7
# Shortest distance from n11 to n86: 6
# Shortest distance from n11 to n87: 6
# Shortest distance from n11 to n88: 9
# Shortest distance from n11 to n89: 7
# Shortest distance from n11 to n90: 3
# Shortest distance from n11 to n91: 2
# Shortest distance from n11 to n92: 6
# Shortest distance from n11 to n93: 4
# Shortest distance from n11 to n94: 6
# Shortest distance from n11 to n95: 4
# Shortest distance from n11 to n96: 4
# Shortest distance from n11 to n97: 3
# Shortest distance from n11 to n98: 5
# Shortest distance from n11 to n99: 7
# Shortest distance from n12 to n0: 4
# Shortest distance from n12 to n1: 6
# Shortest distance from n12 to n2: 2
# Shortest distance from n12 to n3: 4
# Shortest distance from n12 to n4: 1
# Shortest distance from n12 to n5: 2
# Shortest distance from n12 to n6: 5
# Shortest distance from n12 to n7: 6
# Shortest distance from n12 to n8: 5
# Shortest distance from n12 to n9: 3
# Shortest distance from n12 to n10: 6
# Shortest distance from n12 to n11: 5
# Shortest distance from n12 to n13: 10
# Shortest distance from n12 to n14: 8
# Shortest distance from n12 to n15: 8
# Shortest distance from n12 to n16: 1
# Shortest distance from n12 to n17: 9
# Shortest distance from n12 to n18: 10
# Shortest distance from n12 to n19: 4
# Shortest distance from n12 to n20: 5
# Shortest distance from n12 to n21: 5
# Shortest distance from n12 to n22: 6
# Shortest distance from n12 to n23: 6
# Shortest distance from n12 to n24: 7
# Shortest distance from n12 to n25: 9
# Shortest distance from n12 to n26: 5
# Shortest distance from n12 to n27: 4
# Shortest distance from n12 to n28: 4
# Shortest distance from n12 to n29: 5
# Shortest distance from n12 to n30: 7
# Shortest distance from n12 to n31: 6
# Shortest distance from n12 to n32: 3
# Shortest distance from n12 to n33: 3
# Shortest distance from n12 to n34: 8
# Shortest distance from n12 to n35: 8
# Shortest distance from n12 to n36: 6
# Shortest distance from n12 to n37: 8
# Shortest distance from n12 to n38: 7
# Shortest distance from n12 to n39: 2
# Shortest distance from n12 to n40: 5
# Shortest distance from n12 to n41: 4
# Shortest distance from n12 to n42: 5
# Shortest distance from n12 to n43: 7
# Shortest distance from n12 to n44: 9
# Shortest distance from n12 to n45: 6
# Shortest distance from n12 to n46: 3
# Shortest distance from n12 to n47: 3
# Shortest distance from n12 to n48: 3
# Shortest distance from n12 to n49: 4
# Shortest distance from n12 to n50: 8
# Shortest distance from n12 to n51: 7
# Shortest distance from n12 to n52: 6
# Shortest distance from n12 to n53: 5
# Shortest distance from n12 to n54: 4
# Shortest distance from n12 to n55: 3
# Shortest distance from n12 to n56: 7
# Shortest distance from n12 to n57: 8
# Shortest distance from n12 to n58: 8
# Shortest distance from n12 to n59: 2
# Shortest distance from n12 to n60: 10
# Shortest distance from n12 to n61: 8
# Shortest distance from n12 to n62: 4
# Shortest distance from n12 to n63: 8
# Shortest distance from n12 to n64: 5
# Shortest distance from n12 to n65: 8
# Shortest distance from n12 to n66: 9
# Shortest distance from n12 to n67: 6
# Shortest distance from n12 to n68: 8
# Shortest distance from n12 to n69: 6
# Shortest distance from n12 to n70: 6
# Shortest distance from n12 to n71: 5
# Shortest distance from n12 to n72: 4
# Shortest distance from n12 to n73: 6
# Shortest distance from n12 to n74: 7
# Shortest distance from n12 to n75: 7
# Shortest distance from n12 to n76: 6
# Shortest distance from n12 to n77: 6
# Shortest distance from n12 to n78: 7
# Shortest distance from n12 to n79: 4
# Shortest distance from n12 to n80: 5
# Shortest distance from n12 to n81: 2
# Shortest distance from n12 to n82: 5
# Shortest distance from n12 to n83: 4
# Shortest distance from n12 to n84: 8
# Shortest distance from n12 to n85: 6
# Shortest distance from n12 to n86: 1
# Shortest distance from n12 to n87: 5
# Shortest distance from n12 to n88: 10
# Shortest distance from n12 to n89: 8
# Shortest distance from n12 to n90: 5
# Shortest distance from n12 to n91: 7
# Shortest distance from n12 to n92: 4
# Shortest distance from n12 to n93: 3
# Shortest distance from n12 to n94: 9
# Shortest distance from n12 to n95: 4
# Shortest distance from n12 to n96: 3
# Shortest distance from n12 to n97: 8
# Shortest distance from n12 to n98: 5
# Shortest distance from n12 to n99: 7
# Shortest distance from n13 to n0: 9
# Shortest distance from n13 to n1: 10
# Shortest distance from n13 to n2: 11
# Shortest distance from n13 to n3: 8
# Shortest distance from n13 to n4: 11
# Shortest distance from n13 to n5: 12
# Shortest distance from n13 to n6: 11
# Shortest distance from n13 to n7: 10
# Shortest distance from n13 to n8: 11
# Shortest distance from n13 to n9: 10
# Shortest distance from n13 to n10: 12
# Shortest distance from n13 to n11: 9
# Shortest distance from n13 to n12: 10
# Shortest distance from n13 to n14: 12
# Shortest distance from n13 to n15: 12
# Shortest distance from n13 to n16: 9
# Shortest distance from n13 to n17: 1
# Shortest distance from n13 to n18: 14
# Shortest distance from n13 to n19: 9
# Shortest distance from n13 to n20: 9
# Shortest distance from n13 to n21: 11
# Shortest distance from n13 to n22: 12
# Shortest distance from n13 to n23: 12
# Shortest distance from n13 to n24: 5
# Shortest distance from n13 to n25: 13
# Shortest distance from n13 to n26: 8
# Shortest distance from n13 to n27: 8
# Shortest distance from n13 to n28: 10
# Shortest distance from n13 to n29: 11
# Shortest distance from n13 to n30: 13
# Shortest distance from n13 to n31: 9
# Shortest distance from n13 to n32: 7
# Shortest distance from n13 to n33: 9
# Shortest distance from n13 to n34: 6
# Shortest distance from n13 to n35: 7
# Shortest distance from n13 to n36: 4
# Shortest distance from n13 to n37: 12
# ...
# Shortest distance from n95 to n63: 8
# Shortest distance from n95 to n64: 4
# Shortest distance from n95 to n65: 7
# Shortest distance from n95 to n66: 8
# Shortest distance from n95 to n67: 6
# Shortest distance from n95 to n68: 8
# Shortest distance from n95 to n69: 5
# Shortest distance from n95 to n70: 6
# Shortest distance from n95 to n71: 5
# Shortest distance from n95 to n72: 3
# Shortest distance from n95 to n73: 4
# Shortest distance from n95 to n74: 5
# Shortest distance from n95 to n75: 6
# Shortest distance from n95 to n76: 6
# Shortest distance from n95 to n77: 4
# Shortest distance from n95 to n78: 7
# Shortest distance from n95 to n79: 4
# Shortest distance from n95 to n80: 5
# Shortest distance from n95 to n81: 3
# Shortest distance from n95 to n82: 5
# Shortest distance from n95 to n83: 4
# Shortest distance from n95 to n84: 7
# Shortest distance from n95 to n85: 4
# Shortest distance from n95 to n86: 5
# Shortest distance from n95 to n87: 3
# Shortest distance from n95 to n88: 10
# Shortest distance from n95 to n89: 6
# Shortest distance from n95 to n90: 1
# Shortest distance from n95 to n91: 6
# Shortest distance from n95 to n92: 7
# Shortest distance from n95 to n93: 1
# Shortest distance from n95 to n94: 9
# Shortest distance from n95 to n96: 3
# Shortest distance from n95 to n97: 7
# Shortest distance from n95 to n98: 6
# Shortest distance from n95 to n99: 5
# Shortest distance from n96 to n0: 4
# Shortest distance from n96 to n1: 5
# Shortest distance from n96 to n2: 5
# Shortest distance from n96 to n3: 3
# Shortest distance from n96 to n4: 4
# Shortest distance from n96 to n5: 5
# Shortest distance from n96 to n6: 5
# Shortest distance from n96 to n7: 5
# Shortest distance from n96 to n8: 6
# Shortest distance from n96 to n9: 5
# Shortest distance from n96 to n10: 5
# Shortest distance from n96 to n11: 4
# Shortest distance from n96 to n12: 3
# Shortest distance from n96 to n13: 9
# Shortest distance from n96 to n14: 7
# Shortest distance from n96 to n15: 7
# Shortest distance from n96 to n16: 2
# Shortest distance from n96 to n17: 8
# Shortest distance from n96 to n18: 9
# Shortest distance from n96 to n19: 3
# Shortest distance from n96 to n20: 4
# Shortest distance from n96 to n21: 4
# Shortest distance from n96 to n22: 3
# Shortest distance from n96 to n23: 4
# Shortest distance from n96 to n24: 6
# Shortest distance from n96 to n25: 6
# Shortest distance from n96 to n26: 4
# Shortest distance from n96 to n27: 3
# Shortest distance from n96 to n28: 3
# Shortest distance from n96 to n29: 4
# Shortest distance from n96 to n30: 4
# Shortest distance from n96 to n31: 5
# Shortest distance from n96 to n32: 2
# Shortest distance from n96 to n33: 2
# Shortest distance from n96 to n34: 7
# Shortest distance from n96 to n35: 7
# Shortest distance from n96 to n36: 5
# Shortest distance from n96 to n37: 6
# Shortest distance from n96 to n38: 4
# Shortest distance from n96 to n39: 1
# Shortest distance from n96 to n40: 4
# Shortest distance from n96 to n41: 3
# Shortest distance from n96 to n42: 2
# Shortest distance from n96 to n43: 6
# Shortest distance from n96 to n44: 7
# Shortest distance from n96 to n45: 3
# Shortest distance from n96 to n46: 2
# Shortest distance from n96 to n47: 2
# Shortest distance from n96 to n48: 2
# Shortest distance from n96 to n49: 1
# Shortest distance from n96 to n50: 7
# Shortest distance from n96 to n51: 6
# Shortest distance from n96 to n52: 5
# Shortest distance from n96 to n53: 4
# Shortest distance from n96 to n54: 4
# Shortest distance from n96 to n55: 3
# Shortest distance from n96 to n56: 4
# Shortest distance from n96 to n57: 7
# Shortest distance from n96 to n58: 7
# Shortest distance from n96 to n59: 5
# Shortest distance from n96 to n60: 8
# Shortest distance from n96 to n61: 5
# Shortest distance from n96 to n62: 3
# Shortest distance from n96 to n63: 5
# Shortest distance from n96 to n64: 4
# Shortest distance from n96 to n65: 5
# Shortest distance from n96 to n66: 7
# Shortest distance from n96 to n67: 3
# Shortest distance from n96 to n68: 5
# Shortest distance from n96 to n69: 5
# Shortest distance from n96 to n70: 5
# Shortest distance from n96 to n71: 2
# Shortest distance from n96 to n72: 4
# Shortest distance from n96 to n73: 5
# Shortest distance from n96 to n74: 6
# Shortest distance from n96 to n75: 6
# Shortest distance from n96 to n76: 3
# Shortest distance from n96 to n77: 5
# Shortest distance from n96 to n78: 6
# Shortest distance from n96 to n79: 3
# Shortest distance from n96 to n80: 2
# Shortest distance from n96 to n81: 3
# Shortest distance from n96 to n82: 2
# Shortest distance from n96 to n83: 3
# Shortest distance from n96 to n84: 7
# Shortest distance from n96 to n85: 5
# Shortest distance from n96 to n86: 4
# Shortest distance from n96 to n87: 4
# Shortest distance from n96 to n88: 9
# Shortest distance from n96 to n89: 6
# Shortest distance from n96 to n90: 4
# Shortest distance from n96 to n91: 6
# Shortest distance from n96 to n92: 6
# Shortest distance from n96 to n93: 2
# Shortest distance from n96 to n94: 8
# Shortest distance from n96 to n95: 3
# Shortest distance from n96 to n97: 7
# Shortest distance from n96 to n98: 5
# Shortest distance from n96 to n99: 6
# Shortest distance from n97 to n0: 7
# Shortest distance from n97 to n1: 2
# Shortest distance from n97 to n2: 9
# Shortest distance from n97 to n3: 6
# Shortest distance from n97 to n4: 9
# Shortest distance from n97 to n5: 10
# Shortest distance from n97 to n6: 5
# Shortest distance from n97 to n7: 4
# Shortest distance from n97 to n8: 9
# Shortest distance from n97 to n9: 8
# Shortest distance from n97 to n10: 7
# Shortest distance from n97 to n11: 3
# Shortest distance from n97 to n12: 8
# Shortest distance from n97 to n13: 12
# Shortest distance from n97 to n14: 4
# Shortest distance from n97 to n15: 8
# Shortest distance from n97 to n16: 7
# Shortest distance from n97 to n17: 11
# Shortest distance from n97 to n18: 10
# Shortest distance from n97 to n19: 8
# Shortest distance from n97 to n20: 5
# Shortest distance from n97 to n21: 9
# Shortest distance from n97 to n22: 10
# Shortest distance from n97 to n23: 10
# Shortest distance from n97 to n24: 9
# Shortest distance from n97 to n25: 6
# Shortest distance from n97 to n26: 9
# Shortest distance from n97 to n27: 4
# Shortest distance from n97 to n28: 8
# Shortest distance from n97 to n29: 9
# Shortest distance from n97 to n30: 6
# Shortest distance from n97 to n31: 10
# Shortest distance from n97 to n32: 5
# Shortest distance from n97 to n33: 7
# Shortest distance from n97 to n34: 10
# Shortest distance from n97 to n35: 11
# Shortest distance from n97 to n36: 8
# Shortest distance from n97 to n37: 4
# Shortest distance from n97 to n38: 7
# Shortest distance from n97 to n39: 6
# Shortest distance from n97 to n40: 7
# Shortest distance from n97 to n41: 8
# Shortest distance from n97 to n42: 9
# Shortest distance from n97 to n43: 9
# Shortest distance from n97 to n44: 5
# Shortest distance from n97 to n45: 7
# Shortest distance from n97 to n46: 7
# Shortest distance from n97 to n47: 7
# Shortest distance from n97 to n48: 7
# Shortest distance from n97 to n49: 8
# Shortest distance from n97 to n50: 10
# Shortest distance from n97 to n51: 9
# Shortest distance from n97 to n52: 8
# Shortest distance from n97 to n53: 7
# Shortest distance from n97 to n54: 6
# Shortest distance from n97 to n55: 7
# Shortest distance from n97 to n56: 8
# Shortest distance from n97 to n57: 10
# Shortest distance from n97 to n58: 10
# Shortest distance from n97 to n59: 10
# Shortest distance from n97 to n60: 6
# Shortest distance from n97 to n61: 5
# Shortest distance from n97 to n62: 6
# Shortest distance from n97 to n63: 6
# Shortest distance from n97 to n64: 5
# Shortest distance from n97 to n65: 7
# Shortest distance from n97 to n66: 5
# Shortest distance from n97 to n67: 9
# Shortest distance from n97 to n68: 7
# Shortest distance from n97 to n69: 6
# Shortest distance from n97 to n70: 6
# Shortest distance from n97 to n71: 7
# Shortest distance from n97 to n72: 8
# Shortest distance from n97 to n73: 10
# Shortest distance from n97 to n74: 9
# Shortest distance from n97 to n75: 3
# Shortest distance from n97 to n76: 6
# Shortest distance from n97 to n77: 10
# Shortest distance from n97 to n78: 7
# Shortest distance from n97 to n79: 6
# Shortest distance from n97 to n80: 9
# Shortest distance from n97 to n81: 8
# Shortest distance from n97 to n82: 9
# Shortest distance from n97 to n83: 6
# Shortest distance from n97 to n84: 10
# Shortest distance from n97 to n85: 10
# Shortest distance from n97 to n86: 9
# Shortest distance from n97 to n87: 9
# Shortest distance from n97 to n88: 12
# Shortest distance from n97 to n89: 8
# Shortest distance from n97 to n90: 6
# Shortest distance from n97 to n91: 1
# Shortest distance from n97 to n92: 9
# Shortest distance from n97 to n93: 7
# Shortest distance from n97 to n94: 9
# Shortest distance from n97 to n95: 7
# Shortest distance from n97 to n96: 7
# Shortest distance from n97 to n98: 8
# Shortest distance from n97 to n99: 10
# Shortest distance from n98 to n0: 1
# Shortest distance from n98 to n1: 6
# Shortest distance from n98 to n2: 3
# Shortest distance from n98 to n3: 4
# Shortest distance from n98 to n4: 4
# Shortest distance from n98 to n5: 5
# Shortest distance from n98 to n6: 7
# Shortest distance from n98 to n7: 6
# Shortest distance from n98 to n8: 1
# Shortest distance from n98 to n9: 2
# Shortest distance from n98 to n10: 8
# Shortest distance from n98 to n11: 5
# Shortest distance from n98 to n12: 5
# Shortest distance from n98 to n13: 10
# Shortest distance from n98 to n14: 8
# Shortest distance from n98 to n15: 8
# Shortest distance from n98 to n16: 5
# Shortest distance from n98 to n17: 9
# Shortest distance from n98 to n18: 10
# Shortest distance from n98 to n19: 6
# Shortest distance from n98 to n20: 5
# Shortest distance from n98 to n21: 7
# Shortest distance from n98 to n22: 8
# Shortest distance from n98 to n23: 8
# Shortest distance from n98 to n24: 7
# Shortest distance from n98 to n25: 10
# Shortest distance from n98 to n26: 7
# Shortest distance from n98 to n27: 4
# Shortest distance from n98 to n28: 6
# Shortest distance from n98 to n29: 7
# Shortest distance from n98 to n30: 9
# Shortest distance from n98 to n31: 8
# Shortest distance from n98 to n32: 3
# Shortest distance from n98 to n33: 5
# Shortest distance from n98 to n34: 6
# Shortest distance from n98 to n35: 9
# Shortest distance from n98 to n36: 6
# Shortest distance from n98 to n37: 8
# Shortest distance from n98 to n38: 9
# Shortest distance from n98 to n39: 4
# Shortest distance from n98 to n40: 5
# Shortest distance from n98 to n41: 6
# Shortest distance from n98 to n42: 7
# Shortest distance from n98 to n43: 7
# Shortest distance from n98 to n44: 9
# Shortest distance from n98 to n45: 8
# Shortest distance from n98 to n46: 5
# Shortest distance from n98 to n47: 5
# Shortest distance from n98 to n48: 5
# Shortest distance from n98 to n49: 6
# Shortest distance from n98 to n50: 8
# Shortest distance from n98 to n51: 5
# Shortest distance from n98 to n52: 4
# Shortest distance from n98 to n53: 3
# Shortest distance from n98 to n54: 6
# Shortest distance from n98 to n55: 6
# Shortest distance from n98 to n56: 9
# Shortest distance from n98 to n57: 6
# Shortest distance from n98 to n58: 8
# Shortest distance from n98 to n59: 7
# Shortest distance from n98 to n60: 10
# Shortest distance from n98 to n61: 9
# Shortest distance from n98 to n62: 4
# Shortest distance from n98 to n63: 10
# Shortest distance from n98 to n64: 5
# Shortest distance from n98 to n65: 10
# Shortest distance from n98 to n66: 9
# Shortest distance from n98 to n67: 8
# Shortest distance from n98 to n68: 10
# Shortest distance from n98 to n69: 6
# Shortest distance from n98 to n70: 6
# Shortest distance from n98 to n71: 7
# Shortest distance from n98 to n72: 7
# Shortest distance from n98 to n73: 8
# Shortest distance from n98 to n74: 9
# Shortest distance from n98 to n75: 7
# Shortest distance from n98 to n76: 6
# Shortest distance from n98 to n77: 8
# Shortest distance from n98 to n78: 7
# Shortest distance from n98 to n79: 2
# Shortest distance from n98 to n80: 7
# Shortest distance from n98 to n81: 6
# Shortest distance from n98 to n82: 7
# Shortest distance from n98 to n83: 4
# Shortest distance from n98 to n84: 8
# Shortest distance from n98 to n85: 8
# Shortest distance from n98 to n86: 6
# Shortest distance from n98 to n87: 7
# Shortest distance from n98 to n88: 10
# Shortest distance from n98 to n89: 10
# Shortest distance from n98 to n90: 7
# Shortest distance from n98 to n91: 7
# Shortest distance from n98 to n92: 2
# Shortest distance from n98 to n93: 5
# Shortest distance from n98 to n94: 9
# Shortest distance from n98 to n95: 6
# Shortest distance from n98 to n96: 5
# Shortest distance from n98 to n97: 8
# Shortest distance from n98 to n99: 8
# Shortest distance from n99 to n0: 7
# Shortest distance from n99 to n1: 8
# Shortest distance from n99 to n2: 9
# Shortest distance from n99 to n3: 6
# Shortest distance from n99 to n4: 8
# Shortest distance from n99 to n5: 9
# Shortest distance from n99 to n6: 7
# Shortest distance from n99 to n7: 8
# Shortest distance from n99 to n8: 9
# Shortest distance from n99 to n9: 8
# Shortest distance from n99 to n10: 7
# Shortest distance from n99 to n11: 7
# Shortest distance from n99 to n12: 7
# Shortest distance from n99 to n13: 6
# Shortest distance from n99 to n14: 10
# Shortest distance from n99 to n15: 10
# Shortest distance from n99 to n16: 6
# Shortest distance from n99 to n17: 5
# Shortest distance from n99 to n18: 12
# Shortest distance from n99 to n19: 3
# Shortest distance from n99 to n20: 7
# Shortest distance from n99 to n21: 6
# Shortest distance from n99 to n22: 8
# Shortest distance from n99 to n23: 7
# Shortest distance from n99 to n24: 1
# Shortest distance from n99 to n25: 7
# Shortest distance from n99 to n26: 2
# Shortest distance from n99 to n27: 6
# Shortest distance from n99 to n28: 5
# Shortest distance from n99 to n29: 6
# Shortest distance from n99 to n30: 7
# Shortest distance from n99 to n31: 3
# Shortest distance from n99 to n32: 5
# Shortest distance from n99 to n33: 6
# Shortest distance from n99 to n34: 2
# Shortest distance from n99 to n35: 1
# Shortest distance from n99 to n36: 2
# Shortest distance from n99 to n37: 9
# Shortest distance from n99 to n38: 9
# Shortest distance from n99 to n39: 5
# Shortest distance from n99 to n40: 3
# Shortest distance from n99 to n41: 7
# Shortest distance from n99 to n42: 8
# Shortest distance from n99 to n43: 3
# Shortest distance from n99 to n44: 8
# Shortest distance from n99 to n45: 8
# Shortest distance from n99 to n46: 6
# Shortest distance from n99 to n47: 6
# Shortest distance from n99 to n48: 6
# Shortest distance from n99 to n49: 7
# Shortest distance from n99 to n50: 4
# Shortest distance from n99 to n51: 3
# Shortest distance from n99 to n52: 4
# Shortest distance from n99 to n53: 5
# Shortest distance from n99 to n54: 6
# Shortest distance from n99 to n55: 5
# Shortest distance from n99 to n56: 9
# Shortest distance from n99 to n57: 4
# Shortest distance from n99 to n58: 2
# Shortest distance from n99 to n59: 9
# Shortest distance from n99 to n60: 9
# Shortest distance from n99 to n61: 8
# Shortest distance from n99 to n62: 4
# Shortest distance from n99 to n63: 9
# Shortest distance from n99 to n64: 7
# Shortest distance from n99 to n65: 6
# Shortest distance from n99 to n66: 10
# Shortest distance from n99 to n67: 9
# Shortest distance from n99 to n68: 8
# Shortest distance from n99 to n69: 8
# Shortest distance from n99 to n70: 8
# Shortest distance from n99 to n71: 8
# Shortest distance from n99 to n72: 6
# Shortest distance from n99 to n73: 3
# Shortest distance from n99 to n74: 4
# Shortest distance from n99 to n75: 9
# Shortest distance from n99 to n76: 8
# Shortest distance from n99 to n77: 1
# Shortest distance from n99 to n78: 9
# Shortest distance from n99 to n79: 6
# Shortest distance from n99 to n80: 8
# Shortest distance from n99 to n81: 6
# Shortest distance from n99 to n82: 8
# Shortest distance from n99 to n83: 6
# Shortest distance from n99 to n84: 2
# Shortest distance from n99 to n85: 7
# Shortest distance from n99 to n86: 8
# Shortest distance from n99 to n87: 6
# Shortest distance from n99 to n88: 6
# Shortest distance from n99 to n89: 5
# Shortest distance from n99 to n90: 6
# Shortest distance from n99 to n91: 9
# Shortest distance from n99 to n92: 9
# Shortest distance from n99 to n93: 4
# Shortest distance from n99 to n94: 11
# Shortest distance from n99 to n95: 5
# Shortest distance from n99 to n96: 6
# Shortest distance from n99 to n97: 10
# Shortest distance from n99 to n98: 8

# %%
# Drawing Distance Matrix:
fig, ax = plot_distance_matrix_with_weights(distance_matrix, node_ids)
plt.show()

# %% [markdown]
# ## project it using at least two different projections (MDS, t-SNE, ISOMAP)

# %% [markdown]
# Preliminary adjustments on the distance matrix format:

# %%
# Convert the distance matrix to a NumPy array
distance_matrix_np = np.array(distance_matrix)

# %% [markdown]
# ### MDS

# %%
n_components = 2  
mds = MDS(n_components=n_components)

# Fit the MDS model to your data
mds_distance_matrix_reduced = mds.fit_transform(distance_matrix_np)

print('Dimesnion of X after MDS = ',mds_distance_matrix_reduced.shape)
# Out:
# c:\Users\Prathik Matthai\Downloads\Data-Visualization-CurryPasta\.venv\Lib\site-packages\sklearn\manifold\_mds.py:632: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn(
# Dimesnion of X after MDS =  (100, 2)

# %% [markdown]
# ### t-SNE

# %%
# Run t-SNE with precomputed distances
tsne = TSNE(
    n_components=2,           # Reduce to 2 dimensions for visualization
    metric='precomputed',     # This is crucial - tells t-SNE we're providing distances
    learning_rate='auto',     
    init='random',            
    perplexity=3,             # Good choice for small datasets
    random_state=42           # For reproducibility
)

# Apply t-SNE to the NumPy array version of the distance matrix
tsne_distance_matrix_reduced = tsne.fit_transform(distance_matrix_np)
print('Dimesnion of X after t-SNE = ', tsne_distance_matrix_reduced.shape)
# Out:
# Dimesnion of X after t-SNE =  (100, 2)

# %% [markdown]
# ### ISOMAP

# %%
# Ensure distance matrix is a numpy array
distance_matrix_np = np.array(distance_matrix)

# Create Isomap object
isomap = Isomap(
    n_components=2,          # Reduce to 2 dimensions
    metric='precomputed',    # Indicate we're using a precomputed distance matrix
    n_neighbors=5            # Number of neighbors to consider for each point
)

# Apply Isomap to the distance matrix
isomap_results = isomap.fit_transform(distance_matrix_np)
print('Dimension of X after Isomap =', isomap_results.shape)
# Out:
# Dimension of X after Isomap = (100, 2)

# %% [markdown]
# ## draw the resulting layouts and compare/discuss the obtained layouts and parameter choices

# %% [markdown]
# ### MDS

# %%
# Plot the reduced data
plt.figure(figsize=(10, 8))
plt.scatter(mds_distance_matrix_reduced[:, 0], mds_distance_matrix_reduced[:, 1], s=50)

# Add labels for each point
for i in range(len(mds_distance_matrix_reduced)):
    node_label = str(i+1)  # Adjust if you have actual node IDs
    plt.annotate(node_label, 
                 (mds_distance_matrix_reduced[i, 0], mds_distance_matrix_reduced[i, 1]), 
                 fontsize=12)

plt.title("MDS of the Distance Matrix")
plt.xlabel("First MDS Component")
plt.ylabel("Second MDS Component")
plt.grid(True)
plt.show()

# %% [markdown]
# ### t-SNE

# %%
# Visualize the result
plt.figure(figsize=(10, 8))
plt.scatter(tsne_distance_matrix_reduced[:, 0], tsne_distance_matrix_reduced[:, 1], s=100)

# Add labels for each point
for i in range(len(tsne_distance_matrix_reduced)):
    node_label = str(i+1)  # Adjust if you have actual node IDs
    plt.annotate(node_label, 
                 (tsne_distance_matrix_reduced[i, 0], tsne_distance_matrix_reduced[i, 1]), 
                 fontsize=12)

plt.title('t-SNE Projection of Distance Matrix')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.grid(True)
plt.show()

# %% [markdown]
# ### ISOMAP

# %%
# Visualize the results
plt.figure(figsize=(10, 8))
plt.scatter(isomap_results[:, 0], isomap_results[:, 1], s=100)

# Add labels for each point
for i in range(len(isomap_results)):
    node_label = str(i+1)  # Adjust if you have actual node IDs
    plt.annotate(node_label, 
                (isomap_results[i, 0], isomap_results[i, 1]), 
                fontsize=12)

plt.title('Isomap Projection of Distance Matrix')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def plot_projection_with_labels_and_weights(projection, node_ids, edges_dict, labels=None, title="Projection", figsize=(10, 8)):
    """
    Plots a 2D projection of nodes with coloring based on labels and edges styled based on weights.

    Parameters:
    - projection: 2D array of shape (n_nodes, 2) containing the coordinates of nodes in the projection.
    - node_ids: List of node IDs corresponding to the projection.
    - edges_dict: List of dictionaries containing edge information, including weights.
    - labels: Dictionary mapping node IDs to labels (optional).
    - title: Title of the plot.
    - figsize: Size of the figure.
    """
    # Create a figure
    plt.figure(figsize=figsize)

    # Define color map for nodes
    cmap = plt.cm.get_cmap('tab10')

    # Plot nodes
    for i, node_id in enumerate(node_ids):
        x, y = projection[i]
        color = cmap(labels[node_id] % 10) if labels else 'blue'
        plt.scatter(x, y, color=color, s=100, label=f"Label {labels[node_id]}" if labels else None)

        # Add node labels
        plt.annotate(node_id, (x, y), fontsize=8, ha='right')

    # Plot edges
    for edge in edges_dict:
        source, target = edge['edge_nodes']
        weight = float(edge.get('weight', 1))  # Default weight is 1
        linestyle = '-' if weight < 2 else '--'  # Different styles based on weight
        linewidth = 1 + weight / 2  # Thicker lines for higher weights

        if source in node_ids and target in node_ids:
            source_idx = node_ids.index(source)
            target_idx = node_ids.index(target)
            x_coords = [projection[source_idx][0], projection[target_idx][0]]
            y_coords = [projection[source_idx][1], projection[target_idx][1]]
            plt.plot(x_coords, y_coords, color='gray', linestyle=linestyle, linewidth=linewidth)

    # Add title and legend
    plt.title(title)
    if labels:
        plt.legend(loc='best', fontsize=8)
    plt.xlabel("Dimension 1")
    plt.ylabel("Dimension 2")
    plt.grid(True)
    plt.show()
