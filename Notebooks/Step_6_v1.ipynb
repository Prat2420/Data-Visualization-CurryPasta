# %% [markdown]
# Possible TO-DOs:
# - color nodes based on labeling;
# - color/have different shapes for edges based on their weights

# %% [markdown]
# # Step 6

# %% [markdown]
# - take the input graph (for instance Les Misérables network)
# - compute similarity matrix using graph-theoretic distance
# - project it using at least two different projections (MDS, t-SNE, ISOMAP)
# - draw the resulting layouts
# - compare/discuss the obtained layouts and parameter choices

# %%
import pandas as pd
import numpy as np
import pydot
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, ConnectionPatch
import graphviz
import networkx as nx
from networkx.drawing.nx_pydot import from_pydot
from collections import deque
import os
import math
import random
import re
from pathlib import Path
import matplotlib.cm as cm
from matplotlib.patches import Polygon, Patch, Rectangle
from scipy.spatial import ConvexHull
from sklearn.manifold import MDS, TSNE, Isomap
from sklearn.metrics import pairwise_distances

# %%
#names of the dot files that contain the data:
data_name_1 = "../Dataset/JazzNetwork.dot"
data_name_2 = "../Dataset/LesMiserables.dot" #
data_name_3 = "../Dataset/devonshiredebate_withclusters.dot"
data_name_4 = "../Dataset/g.20.27.dot"
data_name_5 = "../Dataset/g.42.88.dot"
data_name_6 = "../Dataset/GD97.dot"
data_name_7 = "../Dataset/LeagueNetwork.dot" 
data_name_8 = "../Dataset/mesh graph.dot"
data_name_9 = "../Dataset/noname.dot" 
data_name_10 = "../Dataset/polblogs.dot"
data_name_11 = "../Dataset/robot graph.dot"
data_name_12 = "../Dataset/rome.dot"
data_name_13 = "../Dataset/snail graph.dot"

# %% [markdown]
# # Functions

# %%
def floyd_warshall(nodes_dict, edges_dict):
    """
    Implements the Floyd-Warshall algorithm to find shortest paths between all pairs of nodes in a graph.
    
    Input:
    - nodes_dict: A list of dictionaries where each dict contains 'node_id' and other attributes
    - edges_dict: A list of dictionaries where each dict contains 'edge_nodes' (source, target) tuple
                  and other attributes including possibly weight information
    
    Output:
    - distance_matrix: A 2D matrix where distance_matrix[i][j] is the shortest path distance from node i to node j
    - node_ids: The list of node IDs in the order they appear in the distance matrix
    
    Algorithm explanation:
    The Floyd-Warshall algorithm finds shortest paths between all pairs of nodes by:
    1. Initializing a distance matrix D with infinity for all non-adjacent nodes
    2. Setting D[i,i] = 0 for all nodes (distance from a node to itself)
    3. Setting D[i,j] = weight for each direct edge (i,j)
    4. Considering each node k as a potential intermediate in paths between i and j
    5. If going through k yields a shorter path, updating D[i,j] accordingly
    
    Time Complexity: O(|V|³) where |V| is the number of nodes
    Space Complexity: O(|V|²)
    """
    
    # Extract node IDs from nodes_dict
    node_ids = [node['node_id'] for node in nodes_dict]
    n = len(node_ids)
    
    # Create node to index mapping for the matrix
    node_to_idx = {node_id: i for i, node_id in enumerate(node_ids)}
    
    # Initialize distance matrix with infinity
    distance_matrix = [[float('inf') for _ in range(n)] for _ in range(n)]
    
    # Set diagonal elements to 0 (distance from a node to itself)
    for i in range(n):
        distance_matrix[i][i] = 0
    
    # Set edge weights
    for edge in edges_dict:
        source, target = edge['edge_nodes']
        
        # Clean up node IDs (remove quotes if present)
        source = source.strip('"')
        target = target.strip('"')
        
        if source in node_to_idx and target in node_to_idx:
            # Determine the weight - look for a weight attribute, default to 1 if not found
            weight = 1
            if 'weight' in edge:
                try:
                    weight = float(edge['weight'].strip('"'))
                except (ValueError, AttributeError):
                    weight = 1
            elif 'len' in edge:
                try:
                    weight = float(edge['len'].strip('"'))
                except (ValueError, AttributeError):
                    weight = 1
                
            i, j = node_to_idx[source], node_to_idx[target]
            distance_matrix[i][j] = weight
            
            # If the graph is undirected, add the reverse edge as well
            # Uncomment this if your graph is undirected
            # distance_matrix[j][i] = weight
    
    # Floyd-Warshall algorithm
    for k in range(n):
        for i in range(n):
            for j in range(n):
                if distance_matrix[i][j] > distance_matrix[i][k] + distance_matrix[k][j]:
                    distance_matrix[i][j] = distance_matrix[i][k] + distance_matrix[k][j]
    
    return distance_matrix, node_ids

# Example usage
def get_shortest_distance(source, target, distance_matrix, node_ids):
    """
    Get the shortest distance between two nodes.
    
    Input:
    - source: The ID of the source node
    - target: The ID of the target node
    - distance_matrix: The distance matrix from floyd_warshall
    - node_ids: The list of node IDs from floyd_warshall
    
    Output:
    - The shortest distance from source to target
    """
    try:
        i = node_ids.index(source)
        j = node_ids.index(target)
        return distance_matrix[i][j]
    except ValueError:
        return "Node not found in the graph"
    
def plot_distance_matrix_with_weights(distance_matrix, node_ids=None, cmap='viridis_r', figsize=(10, 8)):
    """
    Visualizes the distance matrix from Floyd-Warshall algorithm as a heatmap with annotations.
    
    Parameters:
    - distance_matrix: 2D matrix of shortest path distances between all pairs of nodes
    - node_ids: List of node IDs in the order they appear in the distance matrix (optional)
    - cmap: Colormap to use for the heatmap (default: 'viridis_r')
    - figsize: Figure size (width, height) in inches
    
    Returns:
    - matplotlib figure and axes objects
    """
    import numpy as np
    import matplotlib.pyplot as plt
    
    # Convert to numpy array if not already
    distance_matrix = np.array(distance_matrix)
    
    # Create a masked array for infinity values
    mask = np.isinf(distance_matrix)
    masked_matrix = np.ma.masked_array(distance_matrix, mask)
    
    # Create figure and axes
    fig, ax = plt.subplots(figsize=figsize)
    
    # Plot heatmap
    im = ax.imshow(masked_matrix, cmap=cmap)
    
    # Add colorbar
    cbar = plt.colorbar(im, ax=ax)
    cbar.set_label('Shortest Path Distance')
    
    # Set title and labels
    ax.set_title('Shortest Path Distances (Floyd-Warshall Algorithm)')
    
    if node_ids is not None:
        # Clean node IDs (remove quotes if present)
        clean_node_ids = [nid.strip('"') if isinstance(nid, str) else nid for nid in node_ids]
        
        # Only show node labels if there are not too many
        if len(node_ids) <= 30:
            ax.set_xticks(np.arange(len(node_ids)))
            ax.set_yticks(np.arange(len(node_ids)))
            ax.set_xticklabels(clean_node_ids, rotation=45, ha='right')
            ax.set_yticklabels(clean_node_ids)
    
    ax.set_xlabel('Destination Node')
    ax.set_ylabel('Source Node')
    
    # Add text annotations with distances
    if distance_matrix.shape[0] <= 20:  # Only add annotations for smaller matrices
        for i in range(distance_matrix.shape[0]):
            for j in range(distance_matrix.shape[1]):
                value = distance_matrix[i, j]
                text = 'Inf' if np.isinf(value) else f'{value:.1f}'
                text_color = 'white' if not np.isinf(value) and value > np.nanmean(masked_matrix) else 'black'
                ax.text(j, i, text, ha='center', va='center', color=text_color)
    
    # Add a grid to better separate cells
    ax.set_xticks(np.arange(distance_matrix.shape[1]+1)-.5, minor=True)
    ax.set_yticks(np.arange(distance_matrix.shape[0]+1)-.5, minor=True)
    ax.grid(which="minor", color="w", linestyle='-', linewidth=1)
    
    plt.tight_layout()
    return fig, ax

# %% [markdown]
# # Usage:

# %% [markdown]
# ## take the input graph and compute similarity matrix using graph-theoretic distance

# %%
# Load the graph directly with NetworkX
data_name = data_name_2
dataforfile = os.path.basename(data_name) 
nx_graph = nx.nx_pydot.read_dot(data_name)

# Check graph type
is_directed = nx.is_directed(nx_graph)
print(f"Graph is {'directed' if is_directed else 'undirected'}")

# Extract nodes and edges and their attributes
nodes = nx_graph.nodes(data=True)
edges = nx_graph.edges(data=True)

# Create an array of dictionaries, one for each edge
edges_dict = []
for source, target, attrs in edges:
    # Add the original edge direction
    edge_dict = {
        "edge_nodes": (source, target),
        "directed": is_directed
    }
    
    # Add all attributes from the attrs dictionary
    for attr_name, attr_value in attrs.items():    
        edge_dict[attr_name] = attr_value
    
    edges_dict.append(edge_dict)
    
    # For undirected graphs, add the reverse edge as well
    if not is_directed:
        reverse_edge_dict = {
            "edge_nodes": (target, source),
            "directed": is_directed
        }
        
        # Copy all attributes from the original edge
        for attr_name, attr_value in attrs.items():    
            reverse_edge_dict[attr_name] = attr_value
        
        edges_dict.append(reverse_edge_dict)

nodes_dict = []
for node_id, attrs in nodes:
    node_dict = {
        "node_id": node_id
    }
    
    # Add all attributes from the attrs dictionary
    for attr_name, attr_value in attrs.items():        
        node_dict[attr_name] = attr_value
    
    nodes_dict.append(node_dict)

# Basic graph information
print(f"Number of nodes: {len(nodes)}")
if is_directed:
    print(f"Number of edges: {len(edges)}")
else:
    print(f"Original Number of Edges:  {len(edges)} \n -- after doubling edges -- \nNumber of edges: {len(edges) * (2 if not is_directed else 1)}")
# Out:
# Graph is undirected
# Number of nodes: 77
# Original Number of Edges:  254
#  -- after doubling edges --
# Number of edges: 508

# %% [markdown]
# Calaculating shortest paths for all pairs of nodes in the graph with Floyd-Warshall’s Algorithm. Furthermore, we're calculating the distance matrix, to be able to run MDS, t-SNE and ISOMAP:

# %%
# Compute all-pairs shortest paths
distance_matrix, node_ids = floyd_warshall(nodes_dict, edges_dict)

# Example: Find shortest distance between all possible pairs of two nodes
for source in node_ids:
    for target in node_ids:
        if source != target:
            print(f"Shortest distance from {source} to {target}: {get_shortest_distance(source, target, distance_matrix, node_ids)}")
# Out:
# Shortest distance from 1 to 2: 1.0
# Shortest distance from 1 to 3: 9.0
# Shortest distance from 1 to 4: 9.0
# Shortest distance from 1 to 5: 2.0
# Shortest distance from 1 to 6: 2.0
# Shortest distance from 1 to 7: 2.0
# Shortest distance from 1 to 8: 2.0
# Shortest distance from 1 to 9: 3.0
# Shortest distance from 1 to 10: 2.0
# Shortest distance from 1 to 11: 6.0
# Shortest distance from 1 to 12: 7.0
# Shortest distance from 1 to 13: 7.0
# Shortest distance from 1 to 14: 7.0
# Shortest distance from 1 to 15: 7.0
# Shortest distance from 1 to 16: 7.0
# Shortest distance from 1 to 24: 9.0
# Shortest distance from 1 to 25: 8.0
# Shortest distance from 1 to 26: 8.0
# Shortest distance from 1 to 27: 9.0
# Shortest distance from 1 to 28: 8.0
# Shortest distance from 1 to 29: 9.0
# Shortest distance from 1 to 30: 8.0
# Shortest distance from 1 to 32: 9.0
# Shortest distance from 1 to 33: 7.0
# Shortest distance from 1 to 34: 8.0
# Shortest distance from 1 to 35: 9.0
# Shortest distance from 1 to 36: 9.0
# Shortest distance from 1 to 37: 8.0
# Shortest distance from 1 to 38: 8.0
# Shortest distance from 1 to 39: 8.0
# Shortest distance from 1 to 44: 9.0
# Shortest distance from 1 to 45: 7.0
# Shortest distance from 1 to 49: 7.0
# Shortest distance from 1 to 50: 8.0
# Shortest distance from 1 to 52: 8.0
# Shortest distance from 1 to 56: 9.0
# Shortest distance from 1 to 59: 8.0
# Shortest distance from 1 to 65: 7.0
# Shortest distance from 1 to 69: 7.0
# Shortest distance from 1 to 70: 7.0
# Shortest distance from 1 to 71: 7.0
# Shortest distance from 1 to 72: 7.0
# Shortest distance from 1 to 73: 7.0
# Shortest distance from 1 to 17: 12.0
# Shortest distance from 1 to 18: 10.0
# Shortest distance from 1 to 19: 12.0
# Shortest distance from 1 to 20: 12.0
# Shortest distance from 1 to 21: 13.0
# Shortest distance from 1 to 22: 13.0
# Shortest distance from 1 to 23: 13.0
# Shortest distance from 1 to 31: 10.0
# Shortest distance from 1 to 42: 8.0
# Shortest distance from 1 to 43: 9.0
# Shortest distance from 1 to 51: 9.0
# Shortest distance from 1 to 40: 9.0
# Shortest distance from 1 to 41: 9.0
# Shortest distance from 1 to 76: 8.0
# Shortest distance from 1 to 55: 9.0
# Shortest distance from 1 to 46: 11.0
# Shortest distance from 1 to 53: 9.0
# Shortest distance from 1 to 58: 8.0
# Shortest distance from 1 to 63: 9.0
# Shortest distance from 1 to 47: 9.0
# Shortest distance from 1 to 48: 10.0
# Shortest distance from 1 to 60: 9.0
# Shortest distance from 1 to 61: 8.0
# Shortest distance from 1 to 62: 9.0
# Shortest distance from 1 to 64: 9.0
# Shortest distance from 1 to 66: 9.0
# Shortest distance from 1 to 67: 8.0
# Shortest distance from 1 to 74: 9.0
# Shortest distance from 1 to 75: 9.0
# Shortest distance from 1 to 77: 8.0
# Shortest distance from 1 to 57: 9.0
# Shortest distance from 1 to 54: 9.0
# Shortest distance from 1 to 68: 11.0
# Shortest distance from 2 to 1: 1.0
# Shortest distance from 2 to 3: 8.0
# Shortest distance from 2 to 4: 8.0
# Shortest distance from 2 to 5: 1.0
# Shortest distance from 2 to 6: 1.0
# Shortest distance from 2 to 7: 1.0
# Shortest distance from 2 to 8: 1.0
# Shortest distance from 2 to 9: 2.0
# Shortest distance from 2 to 10: 1.0
# Shortest distance from 2 to 11: 5.0
# Shortest distance from 2 to 12: 6.0
# Shortest distance from 2 to 13: 6.0
# Shortest distance from 2 to 14: 6.0
# Shortest distance from 2 to 15: 6.0
# Shortest distance from 2 to 16: 6.0
# Shortest distance from 2 to 24: 8.0
# Shortest distance from 2 to 25: 7.0
# Shortest distance from 2 to 26: 7.0
# Shortest distance from 2 to 27: 8.0
# Shortest distance from 2 to 28: 7.0
# Shortest distance from 2 to 29: 8.0
# Shortest distance from 2 to 30: 7.0
# Shortest distance from 2 to 32: 8.0
# Shortest distance from 2 to 33: 6.0
# Shortest distance from 2 to 34: 7.0
# Shortest distance from 2 to 35: 8.0
# Shortest distance from 2 to 36: 8.0
# Shortest distance from 2 to 37: 7.0
# Shortest distance from 2 to 38: 7.0
# Shortest distance from 2 to 39: 7.0
# Shortest distance from 2 to 44: 8.0
# Shortest distance from 2 to 45: 6.0
# Shortest distance from 2 to 49: 6.0
# Shortest distance from 2 to 50: 7.0
# Shortest distance from 2 to 52: 7.0
# Shortest distance from 2 to 56: 8.0
# Shortest distance from 2 to 59: 7.0
# Shortest distance from 2 to 65: 6.0
# Shortest distance from 2 to 69: 6.0
# Shortest distance from 2 to 70: 6.0
# Shortest distance from 2 to 71: 6.0
# Shortest distance from 2 to 72: 6.0
# Shortest distance from 2 to 73: 6.0
# Shortest distance from 2 to 17: 11.0
# Shortest distance from 2 to 18: 9.0
# Shortest distance from 2 to 19: 11.0
# Shortest distance from 2 to 20: 11.0
# Shortest distance from 2 to 21: 12.0
# Shortest distance from 2 to 22: 12.0
# Shortest distance from 2 to 23: 12.0
# Shortest distance from 2 to 31: 9.0
# Shortest distance from 2 to 42: 7.0
# Shortest distance from 2 to 43: 8.0
# Shortest distance from 2 to 51: 8.0
# Shortest distance from 2 to 40: 8.0
# Shortest distance from 2 to 41: 8.0
# Shortest distance from 2 to 76: 7.0
# Shortest distance from 2 to 55: 8.0
# Shortest distance from 2 to 46: 10.0
# Shortest distance from 2 to 53: 8.0
# Shortest distance from 2 to 58: 7.0
# Shortest distance from 2 to 63: 8.0
# Shortest distance from 2 to 47: 8.0
# Shortest distance from 2 to 48: 9.0
# Shortest distance from 2 to 60: 8.0
# Shortest distance from 2 to 61: 7.0
# Shortest distance from 2 to 62: 8.0
# Shortest distance from 2 to 64: 8.0
# Shortest distance from 2 to 66: 8.0
# Shortest distance from 2 to 67: 7.0
# Shortest distance from 2 to 74: 8.0
# Shortest distance from 2 to 75: 8.0
# Shortest distance from 2 to 77: 7.0
# Shortest distance from 2 to 57: 8.0
# Shortest distance from 2 to 54: 8.0
# Shortest distance from 2 to 68: 10.0
# Shortest distance from 3 to 1: 9.0
# Shortest distance from 3 to 2: 8.0
# Shortest distance from 3 to 4: 6.0
# Shortest distance from 3 to 5: 9.0
# Shortest distance from 3 to 6: 9.0
# Shortest distance from 3 to 7: 9.0
# Shortest distance from 3 to 8: 9.0
# Shortest distance from 3 to 9: 10.0
# Shortest distance from 3 to 10: 9.0
# Shortest distance from 3 to 11: 3.0
# Shortest distance from 3 to 12: 4.0
# Shortest distance from 3 to 13: 4.0
# Shortest distance from 3 to 14: 4.0
# Shortest distance from 3 to 15: 4.0
# Shortest distance from 3 to 16: 4.0
# Shortest distance from 3 to 24: 6.0
# Shortest distance from 3 to 25: 5.0
# Shortest distance from 3 to 26: 5.0
# Shortest distance from 3 to 27: 6.0
# Shortest distance from 3 to 28: 5.0
# Shortest distance from 3 to 29: 6.0
# Shortest distance from 3 to 30: 5.0
# Shortest distance from 3 to 32: 6.0
# Shortest distance from 3 to 33: 4.0
# Shortest distance from 3 to 34: 5.0
# Shortest distance from 3 to 35: 6.0
# Shortest distance from 3 to 36: 6.0
# Shortest distance from 3 to 37: 5.0
# Shortest distance from 3 to 38: 5.0
# Shortest distance from 3 to 39: 5.0
# Shortest distance from 3 to 44: 6.0
# Shortest distance from 3 to 45: 4.0
# Shortest distance from 3 to 49: 4.0
# Shortest distance from 3 to 50: 5.0
# Shortest distance from 3 to 52: 5.0
# Shortest distance from 3 to 56: 6.0
# Shortest distance from 3 to 59: 5.0
# Shortest distance from 3 to 65: 4.0
# Shortest distance from 3 to 69: 4.0
# Shortest distance from 3 to 70: 4.0
# Shortest distance from 3 to 71: 4.0
# Shortest distance from 3 to 72: 4.0
# Shortest distance from 3 to 73: 4.0
# Shortest distance from 3 to 17: 9.0
# Shortest distance from 3 to 18: 7.0
# Shortest distance from 3 to 19: 9.0
# Shortest distance from 3 to 20: 9.0
# Shortest distance from 3 to 21: 10.0
# Shortest distance from 3 to 22: 10.0
# Shortest distance from 3 to 23: 10.0
# Shortest distance from 3 to 31: 7.0
# Shortest distance from 3 to 42: 5.0
# Shortest distance from 3 to 43: 6.0
# Shortest distance from 3 to 51: 6.0
# Shortest distance from 3 to 40: 6.0
# Shortest distance from 3 to 41: 6.0
# Shortest distance from 3 to 76: 5.0
# Shortest distance from 3 to 55: 6.0
# Shortest distance from 3 to 46: 8.0
# Shortest distance from 3 to 53: 6.0
# Shortest distance from 3 to 58: 5.0
# Shortest distance from 3 to 63: 6.0
# Shortest distance from 3 to 47: 6.0
# Shortest distance from 3 to 48: 7.0
# Shortest distance from 3 to 60: 6.0
# Shortest distance from 3 to 61: 5.0
# Shortest distance from 3 to 62: 6.0
# Shortest distance from 3 to 64: 6.0
# Shortest distance from 3 to 66: 6.0
# Shortest distance from 3 to 67: 5.0
# Shortest distance from 3 to 74: 6.0
# Shortest distance from 3 to 75: 6.0
# Shortest distance from 3 to 77: 5.0
# Shortest distance from 3 to 57: 6.0
# Shortest distance from 3 to 54: 6.0
# Shortest distance from 3 to 68: 8.0
# Shortest distance from 4 to 1: 9.0
# Shortest distance from 4 to 2: 8.0
# Shortest distance from 4 to 3: 6.0
# Shortest distance from 4 to 5: 9.0
# Shortest distance from 4 to 6: 9.0
# Shortest distance from 4 to 7: 9.0
# Shortest distance from 4 to 8: 9.0
# Shortest distance from 4 to 9: 10.0
# Shortest distance from 4 to 10: 9.0
# Shortest distance from 4 to 11: 3.0
# Shortest distance from 4 to 12: 4.0
# Shortest distance from 4 to 13: 4.0
# Shortest distance from 4 to 14: 4.0
# Shortest distance from 4 to 15: 4.0
# Shortest distance from 4 to 16: 4.0
# Shortest distance from 4 to 24: 6.0
# Shortest distance from 4 to 25: 5.0
# Shortest distance from 4 to 26: 5.0
# Shortest distance from 4 to 27: 6.0
# Shortest distance from 4 to 28: 5.0
# Shortest distance from 4 to 29: 6.0
# Shortest distance from 4 to 30: 5.0
# Shortest distance from 4 to 32: 6.0
# Shortest distance from 4 to 33: 4.0
# Shortest distance from 4 to 34: 5.0
# Shortest distance from 4 to 35: 6.0
# Shortest distance from 4 to 36: 6.0
# Shortest distance from 4 to 37: 5.0
# Shortest distance from 4 to 38: 5.0
# Shortest distance from 4 to 39: 5.0
# Shortest distance from 4 to 44: 6.0
# Shortest distance from 4 to 45: 4.0
# Shortest distance from 4 to 49: 4.0
# Shortest distance from 4 to 50: 5.0
# Shortest distance from 4 to 52: 5.0
# Shortest distance from 4 to 56: 6.0
# Shortest distance from 4 to 59: 5.0
# Shortest distance from 4 to 65: 4.0
# Shortest distance from 4 to 69: 4.0
# Shortest distance from 4 to 70: 4.0
# Shortest distance from 4 to 71: 4.0
# Shortest distance from 4 to 72: 4.0
# Shortest distance from 4 to 73: 4.0
# Shortest distance from 4 to 17: 9.0
# Shortest distance from 4 to 18: 7.0
# Shortest distance from 4 to 19: 9.0
# Shortest distance from 4 to 20: 9.0
# Shortest distance from 4 to 21: 10.0
# Shortest distance from 4 to 22: 10.0
# Shortest distance from 4 to 23: 10.0
# Shortest distance from 4 to 31: 7.0
# Shortest distance from 4 to 42: 5.0
# Shortest distance from 4 to 43: 6.0
# Shortest distance from 4 to 51: 6.0
# Shortest distance from 4 to 40: 6.0
# Shortest distance from 4 to 41: 6.0
# Shortest distance from 4 to 76: 5.0
# Shortest distance from 4 to 55: 6.0
# Shortest distance from 4 to 46: 8.0
# Shortest distance from 4 to 53: 6.0
# Shortest distance from 4 to 58: 5.0
# Shortest distance from 4 to 63: 6.0
# Shortest distance from 4 to 47: 6.0
# Shortest distance from 4 to 48: 7.0
# Shortest distance from 4 to 60: 6.0
# Shortest distance from 4 to 61: 5.0
# Shortest distance from 4 to 62: 6.0
# Shortest distance from 4 to 64: 6.0
# Shortest distance from 4 to 66: 6.0
# Shortest distance from 4 to 67: 5.0
# Shortest distance from 4 to 74: 6.0
# Shortest distance from 4 to 75: 6.0
# Shortest distance from 4 to 77: 5.0
# Shortest distance from 4 to 57: 6.0
# Shortest distance from 4 to 54: 6.0
# Shortest distance from 4 to 68: 8.0
# Shortest distance from 5 to 1: 2.0
# Shortest distance from 5 to 2: 1.0
# Shortest distance from 5 to 3: 9.0
# Shortest distance from 5 to 4: 9.0
# Shortest distance from 5 to 6: 2.0
# Shortest distance from 5 to 7: 2.0
# Shortest distance from 5 to 8: 2.0
# Shortest distance from 5 to 9: 3.0
# Shortest distance from 5 to 10: 2.0
# Shortest distance from 5 to 11: 6.0
# Shortest distance from 5 to 12: 7.0
# Shortest distance from 5 to 13: 7.0
# Shortest distance from 5 to 14: 7.0
# Shortest distance from 5 to 15: 7.0
# Shortest distance from 5 to 16: 7.0
# Shortest distance from 5 to 24: 9.0
# Shortest distance from 5 to 25: 8.0
# Shortest distance from 5 to 26: 8.0
# Shortest distance from 5 to 27: 9.0
# Shortest distance from 5 to 28: 8.0
# Shortest distance from 5 to 29: 9.0
# Shortest distance from 5 to 30: 8.0
# Shortest distance from 5 to 32: 9.0
# Shortest distance from 5 to 33: 7.0
# Shortest distance from 5 to 34: 8.0
# Shortest distance from 5 to 35: 9.0
# Shortest distance from 5 to 36: 9.0
# Shortest distance from 5 to 37: 8.0
# Shortest distance from 5 to 38: 8.0
# Shortest distance from 5 to 39: 8.0
# Shortest distance from 5 to 44: 9.0
# Shortest distance from 5 to 45: 7.0
# Shortest distance from 5 to 49: 7.0
# Shortest distance from 5 to 50: 8.0
# Shortest distance from 5 to 52: 8.0
# Shortest distance from 5 to 56: 9.0
# Shortest distance from 5 to 59: 8.0
# Shortest distance from 5 to 65: 7.0
# Shortest distance from 5 to 69: 7.0
# Shortest distance from 5 to 70: 7.0
# Shortest distance from 5 to 71: 7.0
# Shortest distance from 5 to 72: 7.0
# Shortest distance from 5 to 73: 7.0
# Shortest distance from 5 to 17: 12.0
# Shortest distance from 5 to 18: 10.0
# Shortest distance from 5 to 19: 12.0
# Shortest distance from 5 to 20: 12.0
# Shortest distance from 5 to 21: 13.0
# Shortest distance from 5 to 22: 13.0
# Shortest distance from 5 to 23: 13.0
# Shortest distance from 5 to 31: 10.0
# Shortest distance from 5 to 42: 8.0
# Shortest distance from 5 to 43: 9.0
# Shortest distance from 5 to 51: 9.0
# Shortest distance from 5 to 40: 9.0
# Shortest distance from 5 to 41: 9.0
# Shortest distance from 5 to 76: 8.0
# Shortest distance from 5 to 55: 9.0
# Shortest distance from 5 to 46: 11.0
# Shortest distance from 5 to 53: 9.0
# Shortest distance from 5 to 58: 8.0
# Shortest distance from 5 to 63: 9.0
# Shortest distance from 5 to 47: 9.0
# Shortest distance from 5 to 48: 10.0
# Shortest distance from 5 to 60: 9.0
# Shortest distance from 5 to 61: 8.0
# Shortest distance from 5 to 62: 9.0
# Shortest distance from 5 to 64: 9.0
# Shortest distance from 5 to 66: 9.0
# Shortest distance from 5 to 67: 8.0
# Shortest distance from 5 to 74: 9.0
# Shortest distance from 5 to 75: 9.0
# Shortest distance from 5 to 77: 8.0
# Shortest distance from 5 to 57: 9.0
# Shortest distance from 5 to 54: 9.0
# Shortest distance from 5 to 68: 11.0
# Shortest distance from 6 to 1: 2.0
# Shortest distance from 6 to 2: 1.0
# Shortest distance from 6 to 3: 9.0
# Shortest distance from 6 to 4: 9.0
# Shortest distance from 6 to 5: 2.0
# Shortest distance from 6 to 7: 2.0
# Shortest distance from 6 to 8: 2.0
# Shortest distance from 6 to 9: 3.0
# Shortest distance from 6 to 10: 2.0
# Shortest distance from 6 to 11: 6.0
# Shortest distance from 6 to 12: 7.0
# Shortest distance from 6 to 13: 7.0
# Shortest distance from 6 to 14: 7.0
# Shortest distance from 6 to 15: 7.0
# Shortest distance from 6 to 16: 7.0
# Shortest distance from 6 to 24: 9.0
# Shortest distance from 6 to 25: 8.0
# Shortest distance from 6 to 26: 8.0
# Shortest distance from 6 to 27: 9.0
# Shortest distance from 6 to 28: 8.0
# Shortest distance from 6 to 29: 9.0
# Shortest distance from 6 to 30: 8.0
# Shortest distance from 6 to 32: 9.0
# Shortest distance from 6 to 33: 7.0
# Shortest distance from 6 to 34: 8.0
# Shortest distance from 6 to 35: 9.0
# Shortest distance from 6 to 36: 9.0
# Shortest distance from 6 to 37: 8.0
# Shortest distance from 6 to 38: 8.0
# Shortest distance from 6 to 39: 8.0
# Shortest distance from 6 to 44: 9.0
# Shortest distance from 6 to 45: 7.0
# Shortest distance from 6 to 49: 7.0
# Shortest distance from 6 to 50: 8.0
# Shortest distance from 6 to 52: 8.0
# Shortest distance from 6 to 56: 9.0
# Shortest distance from 6 to 59: 8.0
# Shortest distance from 6 to 65: 7.0
# Shortest distance from 6 to 69: 7.0
# Shortest distance from 6 to 70: 7.0
# Shortest distance from 6 to 71: 7.0
# Shortest distance from 6 to 72: 7.0
# Shortest distance from 6 to 73: 7.0
# Shortest distance from 6 to 17: 12.0
# Shortest distance from 6 to 18: 10.0
# Shortest distance from 6 to 19: 12.0
# Shortest distance from 6 to 20: 12.0
# Shortest distance from 6 to 21: 13.0
# Shortest distance from 6 to 22: 13.0
# Shortest distance from 6 to 23: 13.0
# Shortest distance from 6 to 31: 10.0
# Shortest distance from 6 to 42: 8.0
# Shortest distance from 6 to 43: 9.0
# Shortest distance from 6 to 51: 9.0
# Shortest distance from 6 to 40: 9.0
# Shortest distance from 6 to 41: 9.0
# Shortest distance from 6 to 76: 8.0
# Shortest distance from 6 to 55: 9.0
# Shortest distance from 6 to 46: 11.0
# Shortest distance from 6 to 53: 9.0
# Shortest distance from 6 to 58: 8.0
# Shortest distance from 6 to 63: 9.0
# Shortest distance from 6 to 47: 9.0
# Shortest distance from 6 to 48: 10.0
# Shortest distance from 6 to 60: 9.0
# Shortest distance from 6 to 61: 8.0
# Shortest distance from 6 to 62: 9.0
# Shortest distance from 6 to 64: 9.0
# Shortest distance from 6 to 66: 9.0
# Shortest distance from 6 to 67: 8.0
# Shortest distance from 6 to 74: 9.0
# Shortest distance from 6 to 75: 9.0
# Shortest distance from 6 to 77: 8.0
# Shortest distance from 6 to 57: 9.0
# Shortest distance from 6 to 54: 9.0
# Shortest distance from 6 to 68: 11.0
# Shortest distance from 7 to 1: 2.0
# Shortest distance from 7 to 2: 1.0
# Shortest distance from 7 to 3: 9.0
# Shortest distance from 7 to 4: 9.0
# Shortest distance from 7 to 5: 2.0
# Shortest distance from 7 to 6: 2.0
# Shortest distance from 7 to 8: 2.0
# Shortest distance from 7 to 9: 3.0
# Shortest distance from 7 to 10: 2.0
# Shortest distance from 7 to 11: 6.0
# Shortest distance from 7 to 12: 7.0
# Shortest distance from 7 to 13: 7.0
# Shortest distance from 7 to 14: 7.0
# Shortest distance from 7 to 15: 7.0
# Shortest distance from 7 to 16: 7.0
# Shortest distance from 7 to 24: 9.0
# Shortest distance from 7 to 25: 8.0
# Shortest distance from 7 to 26: 8.0
# Shortest distance from 7 to 27: 9.0
# Shortest distance from 7 to 28: 8.0
# Shortest distance from 7 to 29: 9.0
# Shortest distance from 7 to 30: 8.0
# Shortest distance from 7 to 32: 9.0
# Shortest distance from 7 to 33: 7.0
# Shortest distance from 7 to 34: 8.0
# Shortest distance from 7 to 35: 9.0
# Shortest distance from 7 to 36: 9.0
# Shortest distance from 7 to 37: 8.0
# Shortest distance from 7 to 38: 8.0
# Shortest distance from 7 to 39: 8.0
# Shortest distance from 7 to 44: 9.0
# Shortest distance from 7 to 45: 7.0
# Shortest distance from 7 to 49: 7.0
# Shortest distance from 7 to 50: 8.0
# Shortest distance from 7 to 52: 8.0
# Shortest distance from 7 to 56: 9.0
# Shortest distance from 7 to 59: 8.0
# Shortest distance from 7 to 65: 7.0
# Shortest distance from 7 to 69: 7.0
# Shortest distance from 7 to 70: 7.0
# Shortest distance from 7 to 71: 7.0
# Shortest distance from 7 to 72: 7.0
# Shortest distance from 7 to 73: 7.0
# Shortest distance from 7 to 17: 12.0
# Shortest distance from 7 to 18: 10.0
# Shortest distance from 7 to 19: 12.0
# Shortest distance from 7 to 20: 12.0
# Shortest distance from 7 to 21: 13.0
# Shortest distance from 7 to 22: 13.0
# Shortest distance from 7 to 23: 13.0
# Shortest distance from 7 to 31: 10.0
# Shortest distance from 7 to 42: 8.0
# Shortest distance from 7 to 43: 9.0
# Shortest distance from 7 to 51: 9.0
# Shortest distance from 7 to 40: 9.0
# Shortest distance from 7 to 41: 9.0
# Shortest distance from 7 to 76: 8.0
# Shortest distance from 7 to 55: 9.0
# Shortest distance from 7 to 46: 11.0
# Shortest distance from 7 to 53: 9.0
# Shortest distance from 7 to 58: 8.0
# Shortest distance from 7 to 63: 9.0
# Shortest distance from 7 to 47: 9.0
# Shortest distance from 7 to 48: 10.0
# Shortest distance from 7 to 60: 9.0
# Shortest distance from 7 to 61: 8.0
# Shortest distance from 7 to 62: 9.0
# Shortest distance from 7 to 64: 9.0
# Shortest distance from 7 to 66: 9.0
# Shortest distance from 7 to 67: 8.0
# Shortest distance from 7 to 74: 9.0
# Shortest distance from 7 to 75: 9.0
# Shortest distance from 7 to 77: 8.0
# Shortest distance from 7 to 57: 9.0
# Shortest distance from 7 to 54: 9.0
# Shortest distance from 7 to 68: 11.0
# Shortest distance from 8 to 1: 2.0
# Shortest distance from 8 to 2: 1.0
# Shortest distance from 8 to 3: 9.0
# Shortest distance from 8 to 4: 9.0
# Shortest distance from 8 to 5: 2.0
# Shortest distance from 8 to 6: 2.0
# Shortest distance from 8 to 7: 2.0
# Shortest distance from 8 to 9: 3.0
# Shortest distance from 8 to 10: 2.0
# Shortest distance from 8 to 11: 6.0
# Shortest distance from 8 to 12: 7.0
# Shortest distance from 8 to 13: 7.0
# Shortest distance from 8 to 14: 7.0
# Shortest distance from 8 to 15: 7.0
# Shortest distance from 8 to 16: 7.0
# Shortest distance from 8 to 24: 9.0
# Shortest distance from 8 to 25: 8.0
# Shortest distance from 8 to 26: 8.0
# Shortest distance from 8 to 27: 9.0
# Shortest distance from 8 to 28: 8.0
# Shortest distance from 8 to 29: 9.0
# Shortest distance from 8 to 30: 8.0
# Shortest distance from 8 to 32: 9.0
# Shortest distance from 8 to 33: 7.0
# Shortest distance from 8 to 34: 8.0
# Shortest distance from 8 to 35: 9.0
# Shortest distance from 8 to 36: 9.0
# Shortest distance from 8 to 37: 8.0
# Shortest distance from 8 to 38: 8.0
# Shortest distance from 8 to 39: 8.0
# Shortest distance from 8 to 44: 9.0
# Shortest distance from 8 to 45: 7.0
# Shortest distance from 8 to 49: 7.0
# Shortest distance from 8 to 50: 8.0
# Shortest distance from 8 to 52: 8.0
# Shortest distance from 8 to 56: 9.0
# Shortest distance from 8 to 59: 8.0
# Shortest distance from 8 to 65: 7.0
# Shortest distance from 8 to 69: 7.0
# Shortest distance from 8 to 70: 7.0
# Shortest distance from 8 to 71: 7.0
# Shortest distance from 8 to 72: 7.0
# Shortest distance from 8 to 73: 7.0
# Shortest distance from 8 to 17: 12.0
# Shortest distance from 8 to 18: 10.0
# Shortest distance from 8 to 19: 12.0
# Shortest distance from 8 to 20: 12.0
# Shortest distance from 8 to 21: 13.0
# Shortest distance from 8 to 22: 13.0
# Shortest distance from 8 to 23: 13.0
# Shortest distance from 8 to 31: 10.0
# Shortest distance from 8 to 42: 8.0
# Shortest distance from 8 to 43: 9.0
# Shortest distance from 8 to 51: 9.0
# Shortest distance from 8 to 40: 9.0
# Shortest distance from 8 to 41: 9.0
# Shortest distance from 8 to 76: 8.0
# Shortest distance from 8 to 55: 9.0
# Shortest distance from 8 to 46: 11.0
# Shortest distance from 8 to 53: 9.0
# Shortest distance from 8 to 58: 8.0
# Shortest distance from 8 to 63: 9.0
# Shortest distance from 8 to 47: 9.0
# Shortest distance from 8 to 48: 10.0
# Shortest distance from 8 to 60: 9.0
# Shortest distance from 8 to 61: 8.0
# Shortest distance from 8 to 62: 9.0
# Shortest distance from 8 to 64: 9.0
# Shortest distance from 8 to 66: 9.0
# Shortest distance from 8 to 67: 8.0
# Shortest distance from 8 to 74: 9.0
# Shortest distance from 8 to 75: 9.0
# Shortest distance from 8 to 77: 8.0
# Shortest distance from 8 to 57: 9.0
# Shortest distance from 8 to 54: 9.0
# Shortest distance from 8 to 68: 11.0
# Shortest distance from 9 to 1: 3.0
# Shortest distance from 9 to 2: 2.0
# Shortest distance from 9 to 3: 10.0
# Shortest distance from 9 to 4: 10.0
# Shortest distance from 9 to 5: 3.0
# Shortest distance from 9 to 6: 3.0
# Shortest distance from 9 to 7: 3.0
# Shortest distance from 9 to 8: 3.0
# Shortest distance from 9 to 10: 3.0
# Shortest distance from 9 to 11: 7.0
# Shortest distance from 9 to 12: 8.0
# Shortest distance from 9 to 13: 8.0
# Shortest distance from 9 to 14: 8.0
# Shortest distance from 9 to 15: 8.0
# Shortest distance from 9 to 16: 8.0
# Shortest distance from 9 to 24: 10.0
# Shortest distance from 9 to 25: 9.0
# Shortest distance from 9 to 26: 9.0
# Shortest distance from 9 to 27: 10.0
# Shortest distance from 9 to 28: 9.0
# Shortest distance from 9 to 29: 10.0
# Shortest distance from 9 to 30: 9.0
# Shortest distance from 9 to 32: 10.0
# Shortest distance from 9 to 33: 8.0
# Shortest distance from 9 to 34: 9.0
# Shortest distance from 9 to 35: 10.0
# Shortest distance from 9 to 36: 10.0
# Shortest distance from 9 to 37: 9.0
# Shortest distance from 9 to 38: 9.0
# Shortest distance from 9 to 39: 9.0
# Shortest distance from 9 to 44: 10.0
# Shortest distance from 9 to 45: 8.0
# Shortest distance from 9 to 49: 8.0
# Shortest distance from 9 to 50: 9.0
# Shortest distance from 9 to 52: 9.0
# Shortest distance from 9 to 56: 10.0
# Shortest distance from 9 to 59: 9.0
# Shortest distance from 9 to 65: 8.0
# Shortest distance from 9 to 69: 8.0
# Shortest distance from 9 to 70: 8.0
# Shortest distance from 9 to 71: 8.0
# Shortest distance from 9 to 72: 8.0
# Shortest distance from 9 to 73: 8.0
# Shortest distance from 9 to 17: 13.0
# Shortest distance from 9 to 18: 11.0
# Shortest distance from 9 to 19: 13.0
# Shortest distance from 9 to 20: 13.0
# Shortest distance from 9 to 21: 14.0
# Shortest distance from 9 to 22: 14.0
# Shortest distance from 9 to 23: 14.0
# Shortest distance from 9 to 31: 11.0
# Shortest distance from 9 to 42: 9.0
# Shortest distance from 9 to 43: 10.0
# Shortest distance from 9 to 51: 10.0
# Shortest distance from 9 to 40: 10.0
# Shortest distance from 9 to 41: 10.0
# Shortest distance from 9 to 76: 9.0
# Shortest distance from 9 to 55: 10.0
# Shortest distance from 9 to 46: 12.0
# Shortest distance from 9 to 53: 10.0
# Shortest distance from 9 to 58: 9.0
# Shortest distance from 9 to 63: 10.0
# Shortest distance from 9 to 47: 10.0
# Shortest distance from 9 to 48: 11.0
# Shortest distance from 9 to 60: 10.0
# Shortest distance from 9 to 61: 9.0
# Shortest distance from 9 to 62: 10.0
# Shortest distance from 9 to 64: 10.0
# Shortest distance from 9 to 66: 10.0
# Shortest distance from 9 to 67: 9.0
# Shortest distance from 9 to 74: 10.0
# Shortest distance from 9 to 75: 10.0
# Shortest distance from 9 to 77: 9.0
# Shortest distance from 9 to 57: 10.0
# Shortest distance from 9 to 54: 10.0
# Shortest distance from 9 to 68: 12.0
# Shortest distance from 10 to 1: 2.0
# Shortest distance from 10 to 2: 1.0
# Shortest distance from 10 to 3: 9.0
# Shortest distance from 10 to 4: 9.0
# Shortest distance from 10 to 5: 2.0
# Shortest distance from 10 to 6: 2.0
# Shortest distance from 10 to 7: 2.0
# Shortest distance from 10 to 8: 2.0
# Shortest distance from 10 to 9: 3.0
# Shortest distance from 10 to 11: 6.0
# Shortest distance from 10 to 12: 7.0
# Shortest distance from 10 to 13: 7.0
# Shortest distance from 10 to 14: 7.0
# Shortest distance from 10 to 15: 7.0
# Shortest distance from 10 to 16: 7.0
# Shortest distance from 10 to 24: 9.0
# Shortest distance from 10 to 25: 8.0
# Shortest distance from 10 to 26: 8.0
# Shortest distance from 10 to 27: 9.0
# Shortest distance from 10 to 28: 8.0
# Shortest distance from 10 to 29: 9.0
# Shortest distance from 10 to 30: 8.0
# Shortest distance from 10 to 32: 9.0
# Shortest distance from 10 to 33: 7.0
# Shortest distance from 10 to 34: 8.0
# Shortest distance from 10 to 35: 9.0
# Shortest distance from 10 to 36: 9.0
# Shortest distance from 10 to 37: 8.0
# Shortest distance from 10 to 38: 8.0
# Shortest distance from 10 to 39: 8.0
# Shortest distance from 10 to 44: 9.0
# Shortest distance from 10 to 45: 7.0
# Shortest distance from 10 to 49: 7.0
# Shortest distance from 10 to 50: 8.0
# Shortest distance from 10 to 52: 8.0
# Shortest distance from 10 to 56: 9.0
# Shortest distance from 10 to 59: 8.0
# Shortest distance from 10 to 65: 7.0
# Shortest distance from 10 to 69: 7.0
# Shortest distance from 10 to 70: 7.0
# Shortest distance from 10 to 71: 7.0
# Shortest distance from 10 to 72: 7.0
# Shortest distance from 10 to 73: 7.0
# Shortest distance from 10 to 17: 12.0
# Shortest distance from 10 to 18: 10.0
# Shortest distance from 10 to 19: 12.0
# Shortest distance from 10 to 20: 12.0
# Shortest distance from 10 to 21: 13.0
# Shortest distance from 10 to 22: 13.0
# Shortest distance from 10 to 23: 13.0
# Shortest distance from 10 to 31: 10.0
# Shortest distance from 10 to 42: 8.0
# Shortest distance from 10 to 43: 9.0
# Shortest distance from 10 to 51: 9.0
# Shortest distance from 10 to 40: 9.0
# Shortest distance from 10 to 41: 9.0
# Shortest distance from 10 to 76: 8.0
# Shortest distance from 10 to 55: 9.0
# Shortest distance from 10 to 46: 11.0
# Shortest distance from 10 to 53: 9.0
# Shortest distance from 10 to 58: 8.0
# Shortest distance from 10 to 63: 9.0
# Shortest distance from 10 to 47: 9.0
# Shortest distance from 10 to 48: 10.0
# Shortest distance from 10 to 60: 9.0
# Shortest distance from 10 to 61: 8.0
# Shortest distance from 10 to 62: 9.0
# Shortest distance from 10 to 64: 9.0
# Shortest distance from 10 to 66: 9.0
# Shortest distance from 10 to 67: 8.0
# Shortest distance from 10 to 74: 9.0
# Shortest distance from 10 to 75: 9.0
# Shortest distance from 10 to 77: 8.0
# Shortest distance from 10 to 57: 9.0
# Shortest distance from 10 to 54: 9.0
# Shortest distance from 10 to 68: 11.0
# Shortest distance from 11 to 1: 6.0
# Shortest distance from 11 to 2: 5.0
# Shortest distance from 11 to 3: 3.0
# Shortest distance from 11 to 4: 3.0
# Shortest distance from 11 to 5: 6.0
# Shortest distance from 11 to 6: 6.0
# Shortest distance from 11 to 7: 6.0
# Shortest distance from 11 to 8: 6.0
# Shortest distance from 11 to 9: 7.0
# Shortest distance from 11 to 10: 6.0
# Shortest distance from 11 to 12: 1.0
# Shortest distance from 11 to 13: 1.0
# Shortest distance from 11 to 14: 1.0
# Shortest distance from 11 to 15: 1.0
# Shortest distance from 11 to 16: 1.0
# Shortest distance from 11 to 24: 3.0
# Shortest distance from 11 to 25: 2.0
# Shortest distance from 11 to 26: 2.0
# Shortest distance from 11 to 27: 3.0
# Shortest distance from 11 to 28: 2.0
# Shortest distance from 11 to 29: 3.0
# Shortest distance from 11 to 30: 2.0
# Shortest distance from 11 to 32: 3.0
# Shortest distance from 11 to 33: 1.0
# Shortest distance from 11 to 34: 2.0
# Shortest distance from 11 to 35: 3.0
# Shortest distance from 11 to 36: 3.0
# Shortest distance from 11 to 37: 2.0
# Shortest distance from 11 to 38: 2.0
# Shortest distance from 11 to 39: 2.0
# Shortest distance from 11 to 44: 3.0
# Shortest distance from 11 to 45: 1.0
# Shortest distance from 11 to 49: 1.0
# Shortest distance from 11 to 50: 2.0
# Shortest distance from 11 to 52: 2.0
# Shortest distance from 11 to 56: 3.0
# Shortest distance from 11 to 59: 2.0
# Shortest distance from 11 to 65: 1.0
# Shortest distance from 11 to 69: 1.0
# Shortest distance from 11 to 70: 1.0
# Shortest distance from 11 to 71: 1.0
# Shortest distance from 11 to 72: 1.0
# Shortest distance from 11 to 73: 1.0
# Shortest distance from 11 to 17: 6.0
# Shortest distance from 11 to 18: 4.0
# Shortest distance from 11 to 19: 6.0
# Shortest distance from 11 to 20: 6.0
# Shortest distance from 11 to 21: 7.0
# Shortest distance from 11 to 22: 7.0
# Shortest distance from 11 to 23: 7.0
# Shortest distance from 11 to 31: 4.0
# Shortest distance from 11 to 42: 2.0
# Shortest distance from 11 to 43: 3.0
# Shortest distance from 11 to 51: 3.0
# Shortest distance from 11 to 40: 3.0
# Shortest distance from 11 to 41: 3.0
# Shortest distance from 11 to 76: 2.0
# Shortest distance from 11 to 55: 3.0
# Shortest distance from 11 to 46: 5.0
# Shortest distance from 11 to 53: 3.0
# Shortest distance from 11 to 58: 2.0
# Shortest distance from 11 to 63: 3.0
# Shortest distance from 11 to 47: 3.0
# Shortest distance from 11 to 48: 4.0
# Shortest distance from 11 to 60: 3.0
# Shortest distance from 11 to 61: 2.0
# Shortest distance from 11 to 62: 3.0
# Shortest distance from 11 to 64: 3.0
# Shortest distance from 11 to 66: 3.0
# Shortest distance from 11 to 67: 2.0
# Shortest distance from 11 to 74: 3.0
# Shortest distance from 11 to 75: 3.0
# Shortest distance from 11 to 77: 2.0
# Shortest distance from 11 to 57: 3.0
# Shortest distance from 11 to 54: 3.0
# Shortest distance from 11 to 68: 5.0
# Shortest distance from 12 to 1: 7.0
# Shortest distance from 12 to 2: 6.0
# Shortest distance from 12 to 3: 4.0
# Shortest distance from 12 to 4: 4.0
# Shortest distance from 12 to 5: 7.0
# Shortest distance from 12 to 6: 7.0
# Shortest distance from 12 to 7: 7.0
# Shortest distance from 12 to 8: 7.0
# Shortest distance from 12 to 9: 8.0
# Shortest distance from 12 to 10: 7.0
# Shortest distance from 12 to 11: 1.0
# Shortest distance from 12 to 13: 2.0
# Shortest distance from 12 to 14: 2.0
# Shortest distance from 12 to 15: 2.0
# Shortest distance from 12 to 16: 2.0
# Shortest distance from 12 to 24: 4.0
# Shortest distance from 12 to 25: 3.0
# Shortest distance from 12 to 26: 3.0
# Shortest distance from 12 to 27: 4.0
# Shortest distance from 12 to 28: 3.0
# Shortest distance from 12 to 29: 4.0
# Shortest distance from 12 to 30: 3.0
# Shortest distance from 12 to 32: 4.0
# Shortest distance from 12 to 33: 2.0
# Shortest distance from 12 to 34: 3.0
# Shortest distance from 12 to 35: 4.0
# Shortest distance from 12 to 36: 4.0
# Shortest distance from 12 to 37: 3.0
# Shortest distance from 12 to 38: 3.0
# Shortest distance from 12 to 39: 3.0
# Shortest distance from 12 to 44: 4.0
# Shortest distance from 12 to 45: 2.0
# Shortest distance from 12 to 49: 2.0
# Shortest distance from 12 to 50: 3.0
# Shortest distance from 12 to 52: 3.0
# Shortest distance from 12 to 56: 4.0
# Shortest distance from 12 to 59: 3.0
# Shortest distance from 12 to 65: 2.0
# Shortest distance from 12 to 69: 2.0
# Shortest distance from 12 to 70: 2.0
# Shortest distance from 12 to 71: 2.0
# Shortest distance from 12 to 72: 2.0
# Shortest distance from 12 to 73: 2.0
# Shortest distance from 12 to 17: 7.0
# Shortest distance from 12 to 18: 5.0
# Shortest distance from 12 to 19: 7.0
# Shortest distance from 12 to 20: 7.0
# Shortest distance from 12 to 21: 8.0
# Shortest distance from 12 to 22: 8.0
# Shortest distance from 12 to 23: 8.0
# Shortest distance from 12 to 31: 5.0
# Shortest distance from 12 to 42: 3.0
# Shortest distance from 12 to 43: 4.0
# Shortest distance from 12 to 51: 4.0
# Shortest distance from 12 to 40: 4.0
# Shortest distance from 12 to 41: 4.0
# Shortest distance from 12 to 76: 3.0
# Shortest distance from 12 to 55: 4.0
# Shortest distance from 12 to 46: 6.0
# Shortest distance from 12 to 53: 4.0
# Shortest distance from 12 to 58: 3.0
# Shortest distance from 12 to 63: 4.0
# Shortest distance from 12 to 47: 4.0
# Shortest distance from 12 to 48: 5.0
# Shortest distance from 12 to 60: 4.0
# Shortest distance from 12 to 61: 3.0
# Shortest distance from 12 to 62: 4.0
# Shortest distance from 12 to 64: 4.0
# Shortest distance from 12 to 66: 4.0
# Shortest distance from 12 to 67: 3.0
# Shortest distance from 12 to 74: 4.0
# Shortest distance from 12 to 75: 4.0
# Shortest distance from 12 to 77: 3.0
# Shortest distance from 12 to 57: 4.0
# Shortest distance from 12 to 54: 4.0
# Shortest distance from 12 to 68: 6.0
# Shortest distance from 13 to 1: 7.0
# Shortest distance from 13 to 2: 6.0
# Shortest distance from 13 to 3: 4.0
# Shortest distance from 13 to 4: 4.0
# Shortest distance from 13 to 5: 7.0
# Shortest distance from 13 to 6: 7.0
# Shortest distance from 13 to 7: 7.0
# Shortest distance from 13 to 8: 7.0
# Shortest distance from 13 to 9: 8.0
# Shortest distance from 13 to 10: 7.0
# Shortest distance from 13 to 11: 1.0
# Shortest distance from 13 to 12: 2.0
# Shortest distance from 13 to 14: 2.0
# Shortest distance from 13 to 15: 2.0
# Shortest distance from 13 to 16: 2.0
# Shortest distance from 13 to 24: 2.0
# Shortest distance from 13 to 25: 3.0
# Shortest distance from 13 to 26: 3.0
# Shortest distance from 13 to 27: 4.0
# Shortest distance from 13 to 28: 3.0
# Shortest distance from 13 to 29: 4.0
# Shortest distance from 13 to 30: 3.0
# Shortest distance from 13 to 32: 4.0
# Shortest distance from 13 to 33: 2.0
# Shortest distance from 13 to 34: 3.0
# Shortest distance from 13 to 35: 4.0
# Shortest distance from 13 to 36: 4.0
# Shortest distance from 13 to 37: 3.0
# Shortest distance from 13 to 38: 3.0
# Shortest distance from 13 to 39: 3.0
# Shortest distance from 13 to 44: 4.0
# Shortest distance from 13 to 45: 2.0
# Shortest distance from 13 to 49: 2.0
# Shortest distance from 13 to 50: 3.0
# Shortest distance from 13 to 52: 3.0
# Shortest distance from 13 to 56: 4.0
# Shortest distance from 13 to 59: 3.0
# Shortest distance from 13 to 65: 2.0
# Shortest distance from 13 to 69: 2.0
# Shortest distance from 13 to 70: 2.0
# Shortest distance from 13 to 71: 2.0
# Shortest distance from 13 to 72: 2.0
# Shortest distance from 13 to 73: 2.0
# Shortest distance from 13 to 17: 5.0
# Shortest distance from 13 to 18: 5.0
# Shortest distance from 13 to 19: 5.0
# Shortest distance from 13 to 20: 5.0
# Shortest distance from 13 to 21: 6.0
# Shortest distance from 13 to 22: 6.0
# Shortest distance from 13 to 23: 6.0
# Shortest distance from 13 to 31: 3.0
# Shortest distance from 13 to 42: 3.0
# Shortest distance from 13 to 43: 4.0
# Shortest distance from 13 to 51: 4.0
# Shortest distance from 13 to 40: 4.0
# Shortest distance from 13 to 41: 4.0
# Shortest distance from 13 to 76: 3.0
# Shortest distance from 13 to 55: 4.0
# Shortest distance from 13 to 46: 6.0
# Shortest distance from 13 to 53: 4.0
# Shortest distance from 13 to 58: 3.0
# Shortest distance from 13 to 63: 4.0
# Shortest distance from 13 to 47: 4.0
# Shortest distance from 13 to 48: 5.0
# Shortest distance from 13 to 60: 4.0
# Shortest distance from 13 to 61: 3.0
# Shortest distance from 13 to 62: 4.0
# Shortest distance from 13 to 64: 4.0
# Shortest distance from 13 to 66: 4.0
# Shortest distance from 13 to 67: 3.0
# Shortest distance from 13 to 74: 4.0
# Shortest distance from 13 to 75: 4.0
# Shortest distance from 13 to 77: 3.0
# Shortest distance from 13 to 57: 4.0
# Shortest distance from 13 to 54: 4.0
# Shortest distance from 13 to 68: 6.0
# Shortest distance from 14 to 1: 7.0
# Shortest distance from 14 to 2: 6.0
# Shortest distance from 14 to 3: 4.0
# Shortest distance from 14 to 4: 4.0
# Shortest distance from 14 to 5: 7.0
# Shortest distance from 14 to 6: 7.0
# Shortest distance from 14 to 7: 7.0
# Shortest distance from 14 to 8: 7.0
# Shortest distance from 14 to 9: 8.0
# Shortest distance from 14 to 10: 7.0
# Shortest distance from 14 to 11: 1.0
# Shortest distance from 14 to 12: 2.0
# Shortest distance from 14 to 13: 2.0
# Shortest distance from 14 to 15: 2.0
# Shortest distance from 14 to 16: 2.0
# Shortest distance from 14 to 24: 4.0
# Shortest distance from 14 to 25: 3.0
# Shortest distance from 14 to 26: 3.0
# Shortest distance from 14 to 27: 4.0
# Shortest distance from 14 to 28: 3.0
# Shortest distance from 14 to 29: 4.0
# Shortest distance from 14 to 30: 3.0
# Shortest distance from 14 to 32: 4.0
# Shortest distance from 14 to 33: 2.0
# Shortest distance from 14 to 34: 3.0
# Shortest distance from 14 to 35: 4.0
# Shortest distance from 14 to 36: 4.0
# Shortest distance from 14 to 37: 3.0
# Shortest distance from 14 to 38: 3.0
# Shortest distance from 14 to 39: 3.0
# Shortest distance from 14 to 44: 4.0
# Shortest distance from 14 to 45: 2.0
# Shortest distance from 14 to 49: 2.0
# Shortest distance from 14 to 50: 3.0
# Shortest distance from 14 to 52: 3.0
# Shortest distance from 14 to 56: 4.0
# Shortest distance from 14 to 59: 3.0
# Shortest distance from 14 to 65: 2.0
# Shortest distance from 14 to 69: 2.0
# Shortest distance from 14 to 70: 2.0
# Shortest distance from 14 to 71: 2.0
# Shortest distance from 14 to 72: 2.0
# Shortest distance from 14 to 73: 2.0
# Shortest distance from 14 to 17: 7.0
# Shortest distance from 14 to 18: 5.0
# Shortest distance from 14 to 19: 7.0
# Shortest distance from 14 to 20: 7.0
# Shortest distance from 14 to 21: 8.0
# Shortest distance from 14 to 22: 8.0
# Shortest distance from 14 to 23: 8.0
# Shortest distance from 14 to 31: 5.0
# Shortest distance from 14 to 42: 3.0
# Shortest distance from 14 to 43: 4.0
# Shortest distance from 14 to 51: 4.0
# Shortest distance from 14 to 40: 4.0
# Shortest distance from 14 to 41: 4.0
# Shortest distance from 14 to 76: 3.0
# Shortest distance from 14 to 55: 4.0
# Shortest distance from 14 to 46: 6.0
# Shortest distance from 14 to 53: 4.0
# Shortest distance from 14 to 58: 3.0
# Shortest distance from 14 to 63: 4.0
# Shortest distance from 14 to 47: 4.0
# Shortest distance from 14 to 48: 5.0
# Shortest distance from 14 to 60: 4.0
# Shortest distance from 14 to 61: 3.0
# Shortest distance from 14 to 62: 4.0
# Shortest distance from 14 to 64: 4.0
# Shortest distance from 14 to 66: 4.0
# Shortest distance from 14 to 67: 3.0
# Shortest distance from 14 to 74: 4.0
# Shortest distance from 14 to 75: 4.0
# Shortest distance from 14 to 77: 3.0
# Shortest distance from 14 to 57: 4.0
# Shortest distance from 14 to 54: 4.0
# Shortest distance from 14 to 68: 6.0
# Shortest distance from 15 to 1: 7.0
# Shortest distance from 15 to 2: 6.0
# Shortest distance from 15 to 3: 4.0
# Shortest distance from 15 to 4: 4.0
# Shortest distance from 15 to 5: 7.0
# Shortest distance from 15 to 6: 7.0
# Shortest distance from 15 to 7: 7.0
# Shortest distance from 15 to 8: 7.0
# Shortest distance from 15 to 9: 8.0
# Shortest distance from 15 to 10: 7.0
# Shortest distance from 15 to 11: 1.0
# Shortest distance from 15 to 12: 2.0
# Shortest distance from 15 to 13: 2.0
# Shortest distance from 15 to 14: 2.0
# Shortest distance from 15 to 16: 2.0
# Shortest distance from 15 to 24: 4.0
# Shortest distance from 15 to 25: 3.0
# Shortest distance from 15 to 26: 3.0
# Shortest distance from 15 to 27: 4.0
# Shortest distance from 15 to 28: 3.0
# Shortest distance from 15 to 29: 4.0
# Shortest distance from 15 to 30: 3.0
# Shortest distance from 15 to 32: 4.0
# Shortest distance from 15 to 33: 2.0
# Shortest distance from 15 to 34: 3.0
# Shortest distance from 15 to 35: 4.0
# Shortest distance from 15 to 36: 4.0
# Shortest distance from 15 to 37: 3.0
# Shortest distance from 15 to 38: 3.0
# Shortest distance from 15 to 39: 3.0
# Shortest distance from 15 to 44: 4.0
# Shortest distance from 15 to 45: 2.0
# Shortest distance from 15 to 49: 2.0
# Shortest distance from 15 to 50: 3.0
# Shortest distance from 15 to 52: 3.0
# Shortest distance from 15 to 56: 4.0
# Shortest distance from 15 to 59: 3.0
# Shortest distance from 15 to 65: 2.0
# Shortest distance from 15 to 69: 2.0
# Shortest distance from 15 to 70: 2.0
# Shortest distance from 15 to 71: 2.0
# Shortest distance from 15 to 72: 2.0
# Shortest distance from 15 to 73: 2.0
# Shortest distance from 15 to 17: 7.0
# Shortest distance from 15 to 18: 5.0
# Shortest distance from 15 to 19: 7.0
# Shortest distance from 15 to 20: 7.0
# Shortest distance from 15 to 21: 8.0
# Shortest distance from 15 to 22: 8.0
# Shortest distance from 15 to 23: 8.0
# Shortest distance from 15 to 31: 5.0
# Shortest distance from 15 to 42: 3.0
# Shortest distance from 15 to 43: 4.0
# Shortest distance from 15 to 51: 4.0
# Shortest distance from 15 to 40: 4.0
# Shortest distance from 15 to 41: 4.0
# Shortest distance from 15 to 76: 3.0
# Shortest distance from 15 to 55: 4.0
# Shortest distance from 15 to 46: 6.0
# Shortest distance from 15 to 53: 4.0
# Shortest distance from 15 to 58: 3.0
# Shortest distance from 15 to 63: 4.0
# Shortest distance from 15 to 47: 4.0
# Shortest distance from 15 to 48: 5.0
# Shortest distance from 15 to 60: 4.0
# Shortest distance from 15 to 61: 3.0
# Shortest distance from 15 to 62: 4.0
# Shortest distance from 15 to 64: 4.0
# Shortest distance from 15 to 66: 4.0
# Shortest distance from 15 to 67: 3.0
# Shortest distance from 15 to 74: 4.0
# Shortest distance from 15 to 75: 4.0
# Shortest distance from 15 to 77: 3.0
# Shortest distance from 15 to 57: 4.0
# Shortest distance from 15 to 54: 4.0
# Shortest distance from 15 to 68: 6.0
# Shortest distance from 16 to 1: 7.0
# Shortest distance from 16 to 2: 6.0
# Shortest distance from 16 to 3: 4.0
# Shortest distance from 16 to 4: 4.0
# Shortest distance from 16 to 5: 7.0
# Shortest distance from 16 to 6: 7.0
# Shortest distance from 16 to 7: 7.0
# Shortest distance from 16 to 8: 7.0
# Shortest distance from 16 to 9: 8.0
# Shortest distance from 16 to 10: 7.0
# Shortest distance from 16 to 11: 1.0
# Shortest distance from 16 to 12: 2.0
# Shortest distance from 16 to 13: 2.0
# Shortest distance from 16 to 14: 2.0
# Shortest distance from 16 to 15: 2.0
# Shortest distance from 16 to 24: 4.0
# Shortest distance from 16 to 25: 3.0
# Shortest distance from 16 to 26: 3.0
# Shortest distance from 16 to 27: 4.0
# Shortest distance from 16 to 28: 3.0
# Shortest distance from 16 to 29: 4.0
# Shortest distance from 16 to 30: 3.0
# Shortest distance from 16 to 32: 4.0
# Shortest distance from 16 to 33: 2.0
# Shortest distance from 16 to 34: 3.0
# Shortest distance from 16 to 35: 4.0
# Shortest distance from 16 to 36: 4.0
# Shortest distance from 16 to 37: 3.0
# Shortest distance from 16 to 38: 3.0
# Shortest distance from 16 to 39: 3.0
# Shortest distance from 16 to 44: 4.0
# Shortest distance from 16 to 45: 2.0
# Shortest distance from 16 to 49: 2.0
# Shortest distance from 16 to 50: 3.0
# Shortest distance from 16 to 52: 3.0
# Shortest distance from 16 to 56: 4.0
# Shortest distance from 16 to 59: 3.0
# Shortest distance from 16 to 65: 2.0
# Shortest distance from 16 to 69: 2.0
# Shortest distance from 16 to 70: 2.0
# Shortest distance from 16 to 71: 2.0
# Shortest distance from 16 to 72: 2.0
# Shortest distance from 16 to 73: 2.0
# Shortest distance from 16 to 17: 7.0
# Shortest distance from 16 to 18: 5.0
# Shortest distance from 16 to 19: 7.0
# Shortest distance from 16 to 20: 7.0
# Shortest distance from 16 to 21: 8.0
# Shortest distance from 16 to 22: 8.0
# Shortest distance from 16 to 23: 8.0
# Shortest distance from 16 to 31: 5.0
# Shortest distance from 16 to 42: 3.0
# Shortest distance from 16 to 43: 4.0
# Shortest distance from 16 to 51: 4.0
# Shortest distance from 16 to 40: 4.0
# Shortest distance from 16 to 41: 4.0
# Shortest distance from 16 to 76: 3.0
# Shortest distance from 16 to 55: 4.0
# Shortest distance from 16 to 46: 6.0
# Shortest distance from 16 to 53: 4.0
# Shortest distance from 16 to 58: 3.0
# Shortest distance from 16 to 63: 4.0
# Shortest distance from 16 to 47: 4.0
# Shortest distance from 16 to 48: 5.0
# Shortest distance from 16 to 60: 4.0
# Shortest distance from 16 to 61: 3.0
# Shortest distance from 16 to 62: 4.0
# Shortest distance from 16 to 64: 4.0
# Shortest distance from 16 to 66: 4.0
# Shortest distance from 16 to 67: 3.0
# Shortest distance from 16 to 74: 4.0
# Shortest distance from 16 to 75: 4.0
# Shortest distance from 16 to 77: 3.0
# Shortest distance from 16 to 57: 4.0
# Shortest distance from 16 to 54: 4.0
# Shortest distance from 16 to 68: 6.0
# Shortest distance from 24 to 1: 9.0
# Shortest distance from 24 to 2: 8.0
# Shortest distance from 24 to 3: 6.0
# Shortest distance from 24 to 4: 6.0
# Shortest distance from 24 to 5: 9.0
# Shortest distance from 24 to 6: 9.0
# Shortest distance from 24 to 7: 9.0
# Shortest distance from 24 to 8: 9.0
# Shortest distance from 24 to 9: 10.0
# Shortest distance from 24 to 10: 9.0
# Shortest distance from 24 to 11: 3.0
# Shortest distance from 24 to 12: 4.0
# Shortest distance from 24 to 13: 2.0
# Shortest distance from 24 to 14: 4.0
# Shortest distance from 24 to 15: 4.0
# Shortest distance from 24 to 16: 4.0
# Shortest distance from 24 to 25: 2.0
# Shortest distance from 24 to 26: 1.0
# Shortest distance from 24 to 27: 2.0
# Shortest distance from 24 to 28: 2.0
# Shortest distance from 24 to 29: 3.0
# Shortest distance from 24 to 30: 1.0
# Shortest distance from 24 to 32: 2.0
# Shortest distance from 24 to 33: 4.0
# Shortest distance from 24 to 34: 3.0
# Shortest distance from 24 to 35: 3.0
# Shortest distance from 24 to 36: 3.0
# Shortest distance from 24 to 37: 2.0
# Shortest distance from 24 to 38: 2.0
# Shortest distance from 24 to 39: 2.0
# Shortest distance from 24 to 44: 3.0
# Shortest distance from 24 to 45: 4.0
# Shortest distance from 24 to 49: 2.0
# Shortest distance from 24 to 50: 4.0
# Shortest distance from 24 to 52: 4.0
# Shortest distance from 24 to 56: 3.0
# Shortest distance from 24 to 59: 4.0
# Shortest distance from 24 to 65: 4.0
# Shortest distance from 24 to 69: 3.0
# Shortest distance from 24 to 70: 3.0
# Shortest distance from 24 to 71: 3.0
# Shortest distance from 24 to 72: 2.0
# Shortest distance from 24 to 73: 3.0
# Shortest distance from 24 to 17: 3.0
# Shortest distance from 24 to 18: 3.0
# Shortest distance from 24 to 19: 3.0
# Shortest distance from 24 to 20: 3.0
# Shortest distance from 24 to 21: 4.0
# Shortest distance from 24 to 22: 4.0
# Shortest distance from 24 to 23: 4.0
# Shortest distance from 24 to 31: 1.0
# Shortest distance from 24 to 42: 3.0
# Shortest distance from 24 to 43: 3.0
# Shortest distance from 24 to 51: 3.0
# Shortest distance from 24 to 40: 2.0
# Shortest distance from 24 to 41: 2.0
# Shortest distance from 24 to 76: 3.0
# Shortest distance from 24 to 55: 3.0
# Shortest distance from 24 to 46: 5.0
# Shortest distance from 24 to 53: 3.0
# Shortest distance from 24 to 58: 3.0
# Shortest distance from 24 to 63: 4.0
# Shortest distance from 24 to 47: 4.0
# Shortest distance from 24 to 48: 5.0
# Shortest distance from 24 to 60: 4.0
# Shortest distance from 24 to 61: 3.0
# Shortest distance from 24 to 62: 4.0
# Shortest distance from 24 to 64: 4.0
# Shortest distance from 24 to 66: 4.0
# Shortest distance from 24 to 67: 3.0
# Shortest distance from 24 to 74: 4.0
# Shortest distance from 24 to 75: 4.0
# Shortest distance from 24 to 77: 3.0
# Shortest distance from 24 to 57: 4.0
# Shortest distance from 24 to 54: 5.0
# Shortest distance from 24 to 68: 6.0
# Shortest distance from 25 to 1: 8.0
# Shortest distance from 25 to 2: 7.0
# Shortest distance from 25 to 3: 5.0
# Shortest distance from 25 to 4: 5.0
# Shortest distance from 25 to 5: 8.0
# Shortest distance from 25 to 6: 8.0
# Shortest distance from 25 to 7: 8.0
# Shortest distance from 25 to 8: 8.0
# Shortest distance from 25 to 9: 9.0
# Shortest distance from 25 to 10: 8.0
# Shortest distance from 25 to 11: 2.0
# Shortest distance from 25 to 12: 3.0
# Shortest distance from 25 to 13: 3.0
# Shortest distance from 25 to 14: 3.0
# Shortest distance from 25 to 15: 3.0
# Shortest distance from 25 to 16: 3.0
# Shortest distance from 25 to 24: 2.0
# Shortest distance from 25 to 26: 3.0
# Shortest distance from 25 to 27: 2.0
# Shortest distance from 25 to 28: 1.0
# Shortest distance from 25 to 29: 2.0
# Shortest distance from 25 to 30: 2.0
# Shortest distance from 25 to 32: 2.0
# Shortest distance from 25 to 33: 3.0
# ...
# Shortest distance from 74 to 32: 4.0
# Shortest distance from 74 to 33: 4.0
# Shortest distance from 74 to 34: 4.0
# Shortest distance from 74 to 35: 6.0
# Shortest distance from 74 to 36: 6.0
# Shortest distance from 74 to 37: 5.0
# Shortest distance from 74 to 38: 5.0
# Shortest distance from 74 to 39: 5.0
# Shortest distance from 74 to 44: 4.0
# Shortest distance from 74 to 45: 4.0
# Shortest distance from 74 to 49: 2.0
# Shortest distance from 74 to 50: 5.0
# Shortest distance from 74 to 52: 5.0
# Shortest distance from 74 to 56: 4.0
# Shortest distance from 74 to 59: 4.0
# Shortest distance from 74 to 65: 4.0
# Shortest distance from 74 to 69: 3.0
# Shortest distance from 74 to 70: 3.0
# Shortest distance from 74 to 71: 4.0
# Shortest distance from 74 to 72: 3.0
# Shortest distance from 74 to 73: 4.0
# Shortest distance from 74 to 17: 7.0
# Shortest distance from 74 to 18: 5.0
# Shortest distance from 74 to 19: 7.0
# Shortest distance from 74 to 20: 7.0
# Shortest distance from 74 to 21: 8.0
# Shortest distance from 74 to 22: 8.0
# Shortest distance from 74 to 23: 8.0
# Shortest distance from 74 to 31: 5.0
# Shortest distance from 74 to 42: 4.0
# Shortest distance from 74 to 43: 5.0
# Shortest distance from 74 to 51: 5.0
# Shortest distance from 74 to 40: 4.0
# Shortest distance from 74 to 41: 4.0
# Shortest distance from 74 to 76: 3.0
# Shortest distance from 74 to 55: 5.0
# Shortest distance from 74 to 46: 6.0
# Shortest distance from 74 to 53: 5.0
# Shortest distance from 74 to 58: 3.0
# Shortest distance from 74 to 63: 4.0
# Shortest distance from 74 to 47: 4.0
# Shortest distance from 74 to 48: 5.0
# Shortest distance from 74 to 60: 4.0
# Shortest distance from 74 to 61: 3.0
# Shortest distance from 74 to 62: 4.0
# Shortest distance from 74 to 64: 4.0
# Shortest distance from 74 to 66: 4.0
# Shortest distance from 74 to 67: 3.0
# Shortest distance from 74 to 75: 3.0
# Shortest distance from 74 to 77: 3.0
# Shortest distance from 74 to 57: 5.0
# Shortest distance from 74 to 54: 6.0
# Shortest distance from 74 to 68: 6.0
# Shortest distance from 75 to 1: 9.0
# Shortest distance from 75 to 2: 8.0
# Shortest distance from 75 to 3: 6.0
# Shortest distance from 75 to 4: 6.0
# Shortest distance from 75 to 5: 9.0
# Shortest distance from 75 to 6: 9.0
# Shortest distance from 75 to 7: 9.0
# Shortest distance from 75 to 8: 9.0
# Shortest distance from 75 to 9: 10.0
# Shortest distance from 75 to 10: 9.0
# Shortest distance from 75 to 11: 3.0
# Shortest distance from 75 to 12: 4.0
# Shortest distance from 75 to 13: 4.0
# Shortest distance from 75 to 14: 4.0
# Shortest distance from 75 to 15: 4.0
# Shortest distance from 75 to 16: 4.0
# Shortest distance from 75 to 24: 4.0
# Shortest distance from 75 to 25: 4.0
# Shortest distance from 75 to 26: 3.0
# Shortest distance from 75 to 27: 4.0
# Shortest distance from 75 to 28: 3.0
# Shortest distance from 75 to 29: 4.0
# Shortest distance from 75 to 30: 4.0
# Shortest distance from 75 to 32: 4.0
# Shortest distance from 75 to 33: 4.0
# Shortest distance from 75 to 34: 4.0
# Shortest distance from 75 to 35: 6.0
# Shortest distance from 75 to 36: 6.0
# Shortest distance from 75 to 37: 5.0
# Shortest distance from 75 to 38: 5.0
# Shortest distance from 75 to 39: 5.0
# Shortest distance from 75 to 44: 4.0
# Shortest distance from 75 to 45: 4.0
# Shortest distance from 75 to 49: 2.0
# Shortest distance from 75 to 50: 5.0
# Shortest distance from 75 to 52: 5.0
# Shortest distance from 75 to 56: 4.0
# Shortest distance from 75 to 59: 4.0
# Shortest distance from 75 to 65: 4.0
# Shortest distance from 75 to 69: 3.0
# Shortest distance from 75 to 70: 3.0
# Shortest distance from 75 to 71: 4.0
# Shortest distance from 75 to 72: 3.0
# Shortest distance from 75 to 73: 4.0
# Shortest distance from 75 to 17: 7.0
# Shortest distance from 75 to 18: 5.0
# Shortest distance from 75 to 19: 7.0
# Shortest distance from 75 to 20: 7.0
# Shortest distance from 75 to 21: 8.0
# Shortest distance from 75 to 22: 8.0
# Shortest distance from 75 to 23: 8.0
# Shortest distance from 75 to 31: 5.0
# Shortest distance from 75 to 42: 4.0
# Shortest distance from 75 to 43: 5.0
# Shortest distance from 75 to 51: 5.0
# Shortest distance from 75 to 40: 4.0
# Shortest distance from 75 to 41: 4.0
# Shortest distance from 75 to 76: 3.0
# Shortest distance from 75 to 55: 5.0
# Shortest distance from 75 to 46: 6.0
# Shortest distance from 75 to 53: 5.0
# Shortest distance from 75 to 58: 3.0
# Shortest distance from 75 to 63: 4.0
# Shortest distance from 75 to 47: 4.0
# Shortest distance from 75 to 48: 5.0
# Shortest distance from 75 to 60: 4.0
# Shortest distance from 75 to 61: 3.0
# Shortest distance from 75 to 62: 4.0
# Shortest distance from 75 to 64: 4.0
# Shortest distance from 75 to 66: 4.0
# Shortest distance from 75 to 67: 3.0
# Shortest distance from 75 to 74: 3.0
# Shortest distance from 75 to 77: 3.0
# Shortest distance from 75 to 57: 5.0
# Shortest distance from 75 to 54: 6.0
# Shortest distance from 75 to 68: 6.0
# Shortest distance from 77 to 1: 8.0
# Shortest distance from 77 to 2: 7.0
# Shortest distance from 77 to 3: 5.0
# Shortest distance from 77 to 4: 5.0
# Shortest distance from 77 to 5: 8.0
# Shortest distance from 77 to 6: 8.0
# Shortest distance from 77 to 7: 8.0
# Shortest distance from 77 to 8: 8.0
# Shortest distance from 77 to 9: 9.0
# Shortest distance from 77 to 10: 8.0
# Shortest distance from 77 to 11: 2.0
# Shortest distance from 77 to 12: 3.0
# Shortest distance from 77 to 13: 3.0
# Shortest distance from 77 to 14: 3.0
# Shortest distance from 77 to 15: 3.0
# Shortest distance from 77 to 16: 3.0
# Shortest distance from 77 to 24: 3.0
# Shortest distance from 77 to 25: 3.0
# Shortest distance from 77 to 26: 2.0
# Shortest distance from 77 to 27: 3.0
# Shortest distance from 77 to 28: 2.0
# Shortest distance from 77 to 29: 3.0
# Shortest distance from 77 to 30: 3.0
# Shortest distance from 77 to 32: 3.0
# Shortest distance from 77 to 33: 3.0
# Shortest distance from 77 to 34: 3.0
# Shortest distance from 77 to 35: 5.0
# Shortest distance from 77 to 36: 5.0
# Shortest distance from 77 to 37: 4.0
# Shortest distance from 77 to 38: 4.0
# Shortest distance from 77 to 39: 4.0
# Shortest distance from 77 to 44: 3.0
# Shortest distance from 77 to 45: 3.0
# Shortest distance from 77 to 49: 1.0
# Shortest distance from 77 to 50: 4.0
# Shortest distance from 77 to 52: 4.0
# Shortest distance from 77 to 56: 2.0
# Shortest distance from 77 to 59: 1.0
# Shortest distance from 77 to 65: 1.0
# Shortest distance from 77 to 69: 2.0
# Shortest distance from 77 to 70: 2.0
# Shortest distance from 77 to 71: 2.0
# Shortest distance from 77 to 72: 2.0
# Shortest distance from 77 to 73: 3.0
# Shortest distance from 77 to 17: 6.0
# Shortest distance from 77 to 18: 3.0
# Shortest distance from 77 to 19: 6.0
# Shortest distance from 77 to 20: 6.0
# Shortest distance from 77 to 21: 6.0
# Shortest distance from 77 to 22: 6.0
# Shortest distance from 77 to 23: 6.0
# Shortest distance from 77 to 31: 4.0
# Shortest distance from 77 to 42: 2.0
# Shortest distance from 77 to 43: 4.0
# Shortest distance from 77 to 51: 4.0
# Shortest distance from 77 to 40: 3.0
# Shortest distance from 77 to 41: 3.0
# Shortest distance from 77 to 76: 2.0
# Shortest distance from 77 to 55: 3.0
# Shortest distance from 77 to 46: 5.0
# Shortest distance from 77 to 53: 4.0
# Shortest distance from 77 to 58: 2.0
# Shortest distance from 77 to 63: 1.0
# Shortest distance from 77 to 47: 3.0
# Shortest distance from 77 to 48: 4.0
# Shortest distance from 77 to 60: 2.0
# Shortest distance from 77 to 61: 2.0
# Shortest distance from 77 to 62: 2.0
# Shortest distance from 77 to 64: 1.0
# Shortest distance from 77 to 66: 1.0
# Shortest distance from 77 to 67: 1.0
# Shortest distance from 77 to 74: 3.0
# Shortest distance from 77 to 75: 3.0
# Shortest distance from 77 to 57: 3.0
# Shortest distance from 77 to 54: 5.0
# Shortest distance from 77 to 68: 5.0
# Shortest distance from 57 to 1: 9.0
# Shortest distance from 57 to 2: 8.0
# Shortest distance from 57 to 3: 6.0
# Shortest distance from 57 to 4: 6.0
# Shortest distance from 57 to 5: 9.0
# Shortest distance from 57 to 6: 9.0
# Shortest distance from 57 to 7: 9.0
# Shortest distance from 57 to 8: 9.0
# Shortest distance from 57 to 9: 10.0
# Shortest distance from 57 to 10: 9.0
# Shortest distance from 57 to 11: 3.0
# Shortest distance from 57 to 12: 4.0
# Shortest distance from 57 to 13: 4.0
# Shortest distance from 57 to 14: 4.0
# Shortest distance from 57 to 15: 4.0
# Shortest distance from 57 to 16: 4.0
# Shortest distance from 57 to 24: 4.0
# Shortest distance from 57 to 25: 3.0
# Shortest distance from 57 to 26: 3.0
# Shortest distance from 57 to 27: 3.0
# Shortest distance from 57 to 28: 4.0
# Shortest distance from 57 to 29: 5.0
# Shortest distance from 57 to 30: 5.0
# Shortest distance from 57 to 32: 5.0
# Shortest distance from 57 to 33: 4.0
# Shortest distance from 57 to 34: 5.0
# Shortest distance from 57 to 35: 6.0
# Shortest distance from 57 to 36: 6.0
# Shortest distance from 57 to 37: 5.0
# Shortest distance from 57 to 38: 5.0
# Shortest distance from 57 to 39: 5.0
# Shortest distance from 57 to 44: 4.0
# Shortest distance from 57 to 45: 4.0
# Shortest distance from 57 to 49: 3.0
# Shortest distance from 57 to 50: 1.0
# Shortest distance from 57 to 52: 4.0
# Shortest distance from 57 to 56: 1.0
# Shortest distance from 57 to 59: 3.0
# Shortest distance from 57 to 65: 3.0
# Shortest distance from 57 to 69: 4.0
# Shortest distance from 57 to 70: 4.0
# Shortest distance from 57 to 71: 4.0
# Shortest distance from 57 to 72: 4.0
# Shortest distance from 57 to 73: 4.0
# Shortest distance from 57 to 17: 6.0
# Shortest distance from 57 to 18: 2.0
# Shortest distance from 57 to 19: 6.0
# Shortest distance from 57 to 20: 6.0
# Shortest distance from 57 to 21: 5.0
# Shortest distance from 57 to 22: 5.0
# Shortest distance from 57 to 23: 5.0
# Shortest distance from 57 to 31: 5.0
# Shortest distance from 57 to 42: 3.0
# Shortest distance from 57 to 43: 4.0
# Shortest distance from 57 to 51: 2.0
# Shortest distance from 57 to 40: 2.0
# Shortest distance from 57 to 41: 4.0
# Shortest distance from 57 to 76: 4.0
# Shortest distance from 57 to 55: 2.0
# Shortest distance from 57 to 46: 7.0
# Shortest distance from 57 to 53: 3.0
# Shortest distance from 57 to 58: 2.0
# Shortest distance from 57 to 63: 4.0
# Shortest distance from 57 to 47: 5.0
# Shortest distance from 57 to 48: 6.0
# Shortest distance from 57 to 60: 4.0
# Shortest distance from 57 to 61: 4.0
# Shortest distance from 57 to 62: 2.0
# Shortest distance from 57 to 64: 2.0
# Shortest distance from 57 to 66: 3.0
# Shortest distance from 57 to 67: 3.0
# Shortest distance from 57 to 74: 5.0
# Shortest distance from 57 to 75: 5.0
# Shortest distance from 57 to 77: 3.0
# Shortest distance from 57 to 54: 5.0
# Shortest distance from 57 to 68: 5.0
# Shortest distance from 54 to 1: 9.0
# Shortest distance from 54 to 2: 8.0
# Shortest distance from 54 to 3: 6.0
# Shortest distance from 54 to 4: 6.0
# Shortest distance from 54 to 5: 9.0
# Shortest distance from 54 to 6: 9.0
# Shortest distance from 54 to 7: 9.0
# Shortest distance from 54 to 8: 9.0
# Shortest distance from 54 to 9: 10.0
# Shortest distance from 54 to 10: 9.0
# Shortest distance from 54 to 11: 3.0
# Shortest distance from 54 to 12: 4.0
# Shortest distance from 54 to 13: 4.0
# Shortest distance from 54 to 14: 4.0
# Shortest distance from 54 to 15: 4.0
# Shortest distance from 54 to 16: 4.0
# Shortest distance from 54 to 24: 5.0
# Shortest distance from 54 to 25: 5.0
# Shortest distance from 54 to 26: 4.0
# Shortest distance from 54 to 27: 3.0
# Shortest distance from 54 to 28: 4.0
# Shortest distance from 54 to 29: 5.0
# Shortest distance from 54 to 30: 5.0
# Shortest distance from 54 to 32: 5.0
# Shortest distance from 54 to 33: 4.0
# Shortest distance from 54 to 34: 5.0
# Shortest distance from 54 to 35: 6.0
# Shortest distance from 54 to 36: 6.0
# Shortest distance from 54 to 37: 5.0
# Shortest distance from 54 to 38: 5.0
# Shortest distance from 54 to 39: 5.0
# Shortest distance from 54 to 44: 4.0
# Shortest distance from 54 to 45: 4.0
# Shortest distance from 54 to 49: 4.0
# Shortest distance from 54 to 50: 4.0
# Shortest distance from 54 to 52: 1.0
# Shortest distance from 54 to 56: 4.0
# Shortest distance from 54 to 59: 5.0
# Shortest distance from 54 to 65: 4.0
# Shortest distance from 54 to 69: 4.0
# Shortest distance from 54 to 70: 4.0
# Shortest distance from 54 to 71: 4.0
# Shortest distance from 54 to 72: 4.0
# Shortest distance from 54 to 73: 4.0
# Shortest distance from 54 to 17: 8.0
# Shortest distance from 54 to 18: 4.0
# Shortest distance from 54 to 19: 8.0
# Shortest distance from 54 to 20: 8.0
# Shortest distance from 54 to 21: 7.0
# Shortest distance from 54 to 22: 7.0
# Shortest distance from 54 to 23: 7.0
# Shortest distance from 54 to 31: 6.0
# Shortest distance from 54 to 42: 5.0
# Shortest distance from 54 to 43: 6.0
# Shortest distance from 54 to 51: 5.0
# Shortest distance from 54 to 40: 3.0
# Shortest distance from 54 to 41: 5.0
# Shortest distance from 54 to 76: 5.0
# Shortest distance from 54 to 55: 3.0
# Shortest distance from 54 to 46: 7.0
# Shortest distance from 54 to 53: 2.0
# Shortest distance from 54 to 58: 5.0
# Shortest distance from 54 to 63: 6.0
# Shortest distance from 54 to 47: 6.0
# Shortest distance from 54 to 48: 7.0
# Shortest distance from 54 to 60: 6.0
# Shortest distance from 54 to 61: 5.0
# Shortest distance from 54 to 62: 5.0
# Shortest distance from 54 to 64: 5.0
# Shortest distance from 54 to 66: 6.0
# Shortest distance from 54 to 67: 5.0
# Shortest distance from 54 to 74: 6.0
# Shortest distance from 54 to 75: 6.0
# Shortest distance from 54 to 77: 5.0
# Shortest distance from 54 to 57: 5.0
# Shortest distance from 54 to 68: 8.0
# Shortest distance from 68 to 1: 11.0
# Shortest distance from 68 to 2: 10.0
# Shortest distance from 68 to 3: 8.0
# Shortest distance from 68 to 4: 8.0
# Shortest distance from 68 to 5: 11.0
# Shortest distance from 68 to 6: 11.0
# Shortest distance from 68 to 7: 11.0
# Shortest distance from 68 to 8: 11.0
# Shortest distance from 68 to 9: 12.0
# Shortest distance from 68 to 10: 11.0
# Shortest distance from 68 to 11: 5.0
# Shortest distance from 68 to 12: 6.0
# Shortest distance from 68 to 13: 6.0
# Shortest distance from 68 to 14: 6.0
# Shortest distance from 68 to 15: 6.0
# Shortest distance from 68 to 16: 6.0
# Shortest distance from 68 to 24: 6.0
# Shortest distance from 68 to 25: 6.0
# Shortest distance from 68 to 26: 5.0
# Shortest distance from 68 to 27: 6.0
# Shortest distance from 68 to 28: 5.0
# Shortest distance from 68 to 29: 6.0
# Shortest distance from 68 to 30: 6.0
# Shortest distance from 68 to 32: 6.0
# Shortest distance from 68 to 33: 6.0
# Shortest distance from 68 to 34: 6.0
# Shortest distance from 68 to 35: 8.0
# Shortest distance from 68 to 36: 8.0
# Shortest distance from 68 to 37: 7.0
# Shortest distance from 68 to 38: 7.0
# Shortest distance from 68 to 39: 7.0
# Shortest distance from 68 to 44: 6.0
# Shortest distance from 68 to 45: 6.0
# Shortest distance from 68 to 49: 4.0
# Shortest distance from 68 to 50: 6.0
# Shortest distance from 68 to 52: 7.0
# Shortest distance from 68 to 56: 4.0
# Shortest distance from 68 to 59: 4.0
# Shortest distance from 68 to 65: 4.0
# Shortest distance from 68 to 69: 5.0
# Shortest distance from 68 to 70: 5.0
# Shortest distance from 68 to 71: 5.0
# Shortest distance from 68 to 72: 5.0
# Shortest distance from 68 to 73: 6.0
# Shortest distance from 68 to 17: 9.0
# Shortest distance from 68 to 18: 5.0
# Shortest distance from 68 to 19: 9.0
# Shortest distance from 68 to 20: 9.0
# Shortest distance from 68 to 21: 8.0
# Shortest distance from 68 to 22: 8.0
# Shortest distance from 68 to 23: 8.0
# Shortest distance from 68 to 31: 7.0
# Shortest distance from 68 to 42: 4.0
# Shortest distance from 68 to 43: 6.0
# Shortest distance from 68 to 51: 7.0
# Shortest distance from 68 to 40: 5.0
# Shortest distance from 68 to 41: 6.0
# Shortest distance from 68 to 76: 5.0
# Shortest distance from 68 to 55: 5.0
# Shortest distance from 68 to 46: 8.0
# Shortest distance from 68 to 53: 6.0
# Shortest distance from 68 to 58: 3.0
# Shortest distance from 68 to 63: 5.0
# Shortest distance from 68 to 47: 6.0
# Shortest distance from 68 to 48: 7.0
# Shortest distance from 68 to 60: 5.0
# Shortest distance from 68 to 61: 5.0
# Shortest distance from 68 to 62: 4.0
# Shortest distance from 68 to 64: 5.0
# Shortest distance from 68 to 66: 4.0
# Shortest distance from 68 to 67: 5.0
# Shortest distance from 68 to 74: 6.0
# Shortest distance from 68 to 75: 6.0
# Shortest distance from 68 to 77: 5.0
# Shortest distance from 68 to 57: 5.0
# Shortest distance from 68 to 54: 8.0

# %%
# Drawing Distance Matrix:
fig, ax = plot_distance_matrix_with_weights(distance_matrix, node_ids)
plt.show()

# %% [markdown]
# ## project it using at least two different projections (MDS, t-SNE, ISOMAP)

# %% [markdown]
# Preliminary adjustments on the distance matrix format:

# %%
# Convert the distance matrix to a NumPy array
distance_matrix_np = np.array(distance_matrix)

# %% [markdown]
# ## draw the resulting layouts

# %% [markdown]
#  create directory for saving output

# %%
import os

# Define the base output directory one level up from current directory
parent_dir = os.path.dirname(os.getcwd())
output_dir = os.path.join(parent_dir, "Step6_output"+ dataforfile)

# Define subdirectories
subdirs = ["MDS", "tSNE", "ISOMAP"]

# Create main output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created main directory: {output_dir}")

# Create subdirectories
for subdir in subdirs:
    subdir_path = os.path.join(output_dir, subdir)
    if not os.path.exists(subdir_path):
        os.makedirs(subdir_path)
        print(f"Created directory: {subdir_path}")
# Out:
# Created main directory: c:\Users\Hari\Desktop\dataVisproj\Data-Visualization-CurryPasta\Step6_outputLesMiserables.dot
# Created directory: c:\Users\Hari\Desktop\dataVisproj\Data-Visualization-CurryPasta\Step6_outputLesMiserables.dot\MDS
# Created directory: c:\Users\Hari\Desktop\dataVisproj\Data-Visualization-CurryPasta\Step6_outputLesMiserables.dot\tSNE
# Created directory: c:\Users\Hari\Desktop\dataVisproj\Data-Visualization-CurryPasta\Step6_outputLesMiserables.dot\ISOMAP

# %% [markdown]
# ### MDS

# %%
n_components = 2  
mds = MDS(n_components=n_components)

# Fit the MDS model to your data
mds_distance_matrix_reduced = mds.fit_transform(distance_matrix_np)

print('Dimesnion of X after MDS = ',mds_distance_matrix_reduced.shape)

# Plot the reduced data
plt.figure(figsize=(10, 8))
plt.scatter(mds_distance_matrix_reduced[:, 0], mds_distance_matrix_reduced[:, 1], s=50)

# add edges
for edge in edges:
    source, target, _ = edge
    source = source.strip('"')
    target = target.strip('"')
    
    # Get the indices of the source and target nodes
    source_idx = node_ids.index(source)
    target_idx = node_ids.index(target)
    
    # Get the coordinates of the source and target nodes
    source_coords = mds_distance_matrix_reduced[source_idx]
    target_coords = mds_distance_matrix_reduced[target_idx]
    
    # Plot the edge
    plt.plot([source_coords[0], target_coords[0]], [source_coords[1], target_coords[1]], 'k-', alpha=0.1)

# Add labels for each point
for i in range(len(mds_distance_matrix_reduced)):
    node_label = str(i+1)  # Adjust if you have actual node IDs
    plt.annotate(node_label, 
                 (mds_distance_matrix_reduced[i, 0], mds_distance_matrix_reduced[i, 1]), 
                 fontsize=12)

plt.title("MDS of the Distance Matrix \n n_components =" + str(n_components))
plt.xlabel("First MDS Component")
plt.ylabel("Second MDS Component")
plt.grid(True)

# Define the output path
parent_dir = os.path.dirname(os.getcwd())
mds_output_dir = os.path.join(parent_dir, "Step6_output"+ dataforfile, "MDS")

# Function to get next available file number
def get_next_file_number():
    existing_files = [f for f in os.listdir(mds_output_dir) 
                     if f.startswith('mds_visualization_') and f.endswith('.png')]
    if not existing_files:
        return 1
    numbers = [int(f.split('_')[2].split('.')[0]) for f in existing_files]
    return max(numbers) + 1

# Save the plot with incremental number
file_number = get_next_file_number()
output_file = os.path.join(mds_output_dir, f"mds_visualization_{file_number}.png")
plt.savefig(output_file, dpi=300, bbox_inches='tight')

# Show the plot after saving
plt.show()

print(f"Plot saved as: {output_file}")
# Out:
# Dimesnion of X after MDS =  (77, 2)
# c:\Users\Hari\Desktop\dataVisproj\Data-Visualization-CurryPasta\my_envi\Lib\site-packages\sklearn\manifold\_mds.py:632: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn(
# Plot saved as: c:\Users\Hari\Desktop\dataVisproj\Data-Visualization-CurryPasta\Step6_outputLesMiserables.dot\MDS\mds_visualization_1.png

# %% [markdown]
# ### t-SNE

# %%
# Run t-SNE with precomputed distances
tsne = TSNE(
    n_components=2,           # Reduce to 2 dimensions for visualization
    metric='precomputed',     # This is crucial - tells t-SNE we're providing distances
    learning_rate='auto',     
    init='random',            
    perplexity=3,             # Good choice for small datasets
    random_state=42           # For reproducibility
)

# Apply t-SNE to the NumPy array version of the distance matrix
tsne_distance_matrix_reduced = tsne.fit_transform(distance_matrix_np)
print('Dimesnion of X after t-SNE = ', tsne_distance_matrix_reduced.shape)

# Get t-SNE parameters for the title
tsne_params = f"perplexity={tsne.perplexity}, learning_rate={tsne.learning_rate}, n_components={tsne.n_components}"

# Visualize the result
plt.figure(figsize=(10, 8))
plt.scatter(tsne_distance_matrix_reduced[:, 0], tsne_distance_matrix_reduced[:, 1], s=100)

# add edges
for edge in edges:
    source, target, _ = edge
    source = source.strip('"')
    target = target.strip('"')
    
    # Get the indices of the source and target nodes
    source_idx = node_ids.index(source)
    target_idx = node_ids.index(target)
    
    # Get the coordinates of the source and target nodes
    source_coords = tsne_distance_matrix_reduced[source_idx]
    target_coords = tsne_distance_matrix_reduced[target_idx]
    
    # Plot the edge
    plt.plot([source_coords[0], target_coords[0]], [source_coords[1], target_coords[1]], 'k-', alpha=0.1)

# Add labels for each point
for i in range(len(tsne_distance_matrix_reduced)):
    node_label = str(i+1)  # Adjust if you have actual node IDs
    plt.annotate(node_label, 
                 (tsne_distance_matrix_reduced[i, 0], tsne_distance_matrix_reduced[i, 1]), 
                 fontsize=12)

plt.title(f't-SNE Projection of Distance Matrix\n({tsne_params})')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.grid(True)
# Define the output path
parent_dir = os.path.dirname(os.getcwd())
mds_output_dir = os.path.join(parent_dir, "Step6_output" + dataforfile, "tSNE")

# Function to get next available file number
def get_next_file_number():
    existing_files = [f for f in os.listdir(mds_output_dir) 
                     if f.startswith('tSNE_visualization_') and f.endswith('.png')]
    if not existing_files:
        return 1
    numbers = [int(f.split('_')[2].split('.')[0]) for f in existing_files]
    return max(numbers) + 1

# Save the plot with incremental number
file_number = get_next_file_number()
output_file = os.path.join(mds_output_dir, f"tSNE_visualization_{file_number}.png")
plt.savefig(output_file, dpi=300, bbox_inches='tight')

# Show the plot after saving
plt.show()

print(f"Plot saved as: {output_file}")
# Out:
# Dimesnion of X after t-SNE =  (77, 2)
# Plot saved as: c:\Users\Hari\Desktop\dataVisproj\Data-Visualization-CurryPasta\Step6_outputLesMiserables.dot\tSNE\tSNE_visualization_1.png

# %% [markdown]
# ### ISOMAP

# %%
# Ensure distance matrix is a numpy array
distance_matrix_np = np.array(distance_matrix)

# Create Isomap object
isomap = Isomap(
    n_components=2,          # Reduce to 2 dimensions
    metric='precomputed',    # Indicate we're using a precomputed distance matrix
    n_neighbors=5            # Number of neighbors to consider for each point
)

# Apply Isomap to the distance matrix
isomap_results = isomap.fit_transform(distance_matrix_np)
print('Dimension of X after Isomap =', isomap_results.shape)

# Get ISOMAP parameters for the title
isomap_params = f"n_components={isomap.n_components}, n_neighbors={isomap.n_neighbors}"

# Visualize the results
plt.figure(figsize=(10, 8))
plt.scatter(isomap_results[:, 0], isomap_results[:, 1], s=100)

# add edges
for edge in edges:
    source, target, _ = edge
    source = source.strip('"')
    target = target.strip('"')
    
    # Get the indices of the source and target nodes
    source_idx = node_ids.index(source)
    target_idx = node_ids.index(target)
    
    # Get the coordinates of the source and target nodes
    source_coords = isomap_results[source_idx]
    target_coords = isomap_results[target_idx]
    
    # Plot the edge
    plt.plot([source_coords[0], target_coords[0]], [source_coords[1], target_coords[1]], 'k-', alpha=0.1)

# Add labels for each point
for i in range(len(isomap_results)):
    node_label = str(i+1)  # Adjust if you have actual node IDs
    plt.annotate(node_label, 
                (isomap_results[i, 0], isomap_results[i, 1]), 
                fontsize=12)

plt.title(f'ISOMAP Projection of Distance Matrix\n({isomap_params})')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.grid(True)
plt.tight_layout()
# Define the output path
parent_dir = os.path.dirname(os.getcwd())
mds_output_dir = os.path.join(parent_dir, "Step6_output"+ dataforfile, "ISOMAP")

# Function to get next available file number
def get_next_file_number():
    existing_files = [f for f in os.listdir(mds_output_dir) 
                     if f.startswith('ISOMAP_visualization_') and f.endswith('.png')]
    if not existing_files:
        return 1
    numbers = [int(f.split('_')[2].split('.')[0]) for f in existing_files]
    return max(numbers) + 1

# Save the plot with incremental number
file_number = get_next_file_number()
output_file = os.path.join(mds_output_dir, f"ISOMAP_visualization_{file_number}.png")
plt.savefig(output_file, dpi=300, bbox_inches='tight')

# Show the plot after saving
plt.show()

print(f"Plot saved as: {output_file}")
# Out:
# Dimension of X after Isomap = (77, 2)
# c:\Users\Hari\Desktop\dataVisproj\Data-Visualization-CurryPasta\my_envi\Lib\site-packages\sklearn\manifold\_isomap.py:384: UserWarning: The number of connected components of the neighbors graph is 2 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# c:\Users\Hari\Desktop\dataVisproj\Data-Visualization-CurryPasta\my_envi\Lib\site-packages\scipy\sparse\_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# Plot saved as: c:\Users\Hari\Desktop\dataVisproj\Data-Visualization-CurryPasta\Step6_outputLesMiserables.dot\ISOMAP\ISOMAP_visualization_1.png
